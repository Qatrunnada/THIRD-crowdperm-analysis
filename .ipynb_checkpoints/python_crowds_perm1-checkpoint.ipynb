# %%
#testing github
#data base connection
import csv
import pandas
from sshtunnel import SSHTunnelForwarder
import pymysql

#specifiy the path for your file
#/Users/QN/Desktop/THIRD crowdperm
with open('/Users/QN/Desktop/THIRD crowdperm/user.txt') as f:
    lines = f.read().splitlines()    
f.close()


server =    SSHTunnelForwarder(
         ('juhu.soic.indiana.edu'),
         ssh_username=lines[0],
         ssh_password=lines[1],
         remote_bind_address=('127.0.0.1', 3306))
server.start()
cnx = pymysql.connect(host='127.0.0.1',
                           port=server.local_bind_port,
                           user='mturk',
                           passwd='m+turk=my-sql',
                           db='mturk')
cnx.set_charset('utf8')

# %%
#prepare survey2 table:
#prepare survey2 file
#write a code to split the column from table app2
#insert the splitted value to survey2 , with the names of the apps as “N/A”
#add the names of the apps to the table too
#allEnabledAppName, allDisabledAppName,PERMISSIONenabled,PERMISSIONdisabled
data=[]
query1 = ("select msg,allEnabledAppName, allDisabledAppName,PERMISSIONenabled,PERMISSIONdisabled from apps2")
cursor1=cnx.cursor()
cursor1.execute(query1)
for row in cursor1:
    
    #print (row[0])
    #print(row[1])#allEnabled
    #print(row[2])#allDisabled
    #print(row[3])#enabled
    #print(row[4])#disabled
    allEnabled=row[1]
    allDisabled=row[2]
    enabledApps=['','','','','']
    disabledApps=['','','','','']
    
    #split the list of apps for enabled and disabled, and if fewer than 5 apps, fill the rest with empty strings
    enabledApps = row[3].split(",") #split string into a list
    disabledApps = row[4].split(",") #split string into a list
    
    if len(enabledApps) <5:
        j=len(enabledApps)
        while j < 5:
            enabledApps.append('')
            j=j+1  

    if len(disabledApps) <5:
        j=len(disabledApps)
        while j < 5:
            disabledApps.append('')
            j=j+1  
    
    print (len(disabledApps))
    print (len(enabledApps))
    #print ("\n")
    msg = row[0].split("#") #split string into a list


    #escape the quotes
    i=0
    while i < len(msg):
        msg[i]=msg[i].replace("'", "\\\'")
        msg[i]=msg[i].replace("\\\\'", "\\\'")
        i=i+1 
   
    #deal with the situation when there are only msg length =58 (before adding the follow up question for the story)
    if len(msg)<65:
        j=len(msg)
        while j < 65 :
            msg.append('')
            j=j+1  
        #move the duration and times to the last 3 columns and fill the previous ones with empty strings
        msg[62]=msg[55]#start
        msg[63]=msg[56]#end
        msg[64]=msg[57]#duration
        msg[55]=''
        msg[56]=''
        msg[57]=''
        msg[58]=''
        msg[59]=''
        msg[60]=''
        msg[61]=''

    len(msg)
    print (len(msg))
    print(msg)
    
    data.append(msg)
    cursor3 = cnx.cursor()
    insertQ = "insert into survey2(randomint,permission,TurkerID,attention1,attention2,attention3,gender,education,race,androidDuration,priorAndroid,canChange,howChange,everChanged,seenMessage,allEnabledAppName,enabledAllaware,enabledAllwhy,allDisabledAppName,disabledAll,PERMISSIONenabled1,PERMISSIONenabled2,PERMISSIONenabled3,PERMISSIONenabled4,PERMISSIONenabled5,comfortableMic,changesettingsMic1,changesettingsissueMic1,problemMic1,changesettingsMic2,changesettingsissueMic2,problemMic2,changesettingsMic3,changesettingsissueMic3,problemMic3,changesettingsMic4,changesettingsissueMic4,problemMic4,changesettingsMic5,changesettingsissueMic5,problemMic5,enabledwhyMic1,enabledwhyMic2,enabledwhyMic3,enabledwhyMic4,enabledwhyMic5,PERMISSIONdisabled1,PERMISSIONdisabled2,PERMISSIONdisabled3,PERMISSIONdisabled4,PERMISSIONdisabled5,disabledawareMic1,disabledwhyMic1,disabledawareMic2,disabledwhyMic2,disabledawareMic3,disabledwhyMic3,disabledawareMic4,disabledwhyMic4,disabledawareMic5,disabledwhyMic5,danger,story,storyPermission,storyApp,storyProblem,storySolve,storyTempEnable,storyEnableComfort,storyBehaviour,storyBehaviourHow,storyReinstall,storyOtherApp,storyUninstallComfort,startTime,endTime,duration) VALUES(%s,%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)"
    number_of_rows = cursor3.execute(insertQ,(msg[0],msg[1],msg[2],msg[3],msg[4],msg[5],msg[6],msg[7],msg[8],msg[9],msg[10],msg[11],msg[12],msg[13],msg[14],allEnabled,msg[15],msg[16],allDisabled,msg[17],enabledApps[0],enabledApps[1],enabledApps[2],enabledApps[3],enabledApps[4],msg[18],msg[19],msg[20], msg[21],msg[22],msg[23],msg[24],msg[25],msg[26],msg[27],msg[28],msg[29],msg[30], msg[31],msg[32],msg[33],msg[34],msg[35],msg[36],msg[37],msg[38],disabledApps[0],disabledApps[1],disabledApps[2],disabledApps[3],disabledApps[4],msg[39],msg[40], msg[41],msg[42],msg[43],msg[44],msg[45],msg[46],msg[47],msg[48],msg[49],msg[50], msg[51],msg[52],msg[53],msg[54],msg[55],msg[56],msg[57],msg[58],msg[59],msg[60], msg[61],msg[62],msg[63],msg[64]))  
    cnx.commit()
    #msg
#cnx.close()
# Out:
# 5
# 5
# 65
# ['72865', 'LOCATION', 'A4IH4CO046EV3', 'Android', 'Rarely', 'Agree', 'Male', 'Some college', 'White', '7-12 months', 'No', 'Yes', 'I would limit everything', 'No', 'Yes', 'Yes', "I want to use a specific feature that requires this permission, I think the app won\\'t work otherwise, I trust the app developer", "I think the app shouldn\\'t need this permission, I can always grant it afterwards if I change my mind", '', 'No', 'NA', 'NA', 'No', 'NA', 'NA', 'No', 'NA', 'NA', 'No', 'NA', 'NA', 'No', 'NA', 'NA', 'I want to use a specific feature that requires this permission', 'I want to use a specific feature that requires this permission', "I didn\\'t know I did that", "I didn\\'t know I did that", "I didn\\'t know I did that", 'No', 'NA', 'No', 'NA', 'No', 'NA', 'Yes', 'I can always grant it afterwards if I change my mind', 'No', 'NA', '2,2,4,4,4,4,1,1,4', 'No', 'NA', 'NA', 'NA', 'NA', '', '', '', '', '', '', '', '21-11-2017-05-43-45', '21-11-2017-05-48-04', '4.3166666666667']
# 5
# 5
# 65
# ['59382', 'MICROPHONE', 'A2BZY06YRWGEDL', 'Android', 'Rarely', 'Agree', 'Male', 'High School', 'White', '7-12 months', 'Yes', 'Yes', "Go into settings and then apps. There\\'s options in there", 'Yes', 'Yes', 'Yes', 'I have nothing to hide, I wanted the permission screen to go away', 'The app did not ask for that permission/I did not disable the permission/I think thatâ€™s the default setting', '4,4,4,4,4', 'Yes', 'Yes', "I didn\\'t feel like going into settings", 'No', 'NA', 'NA', 'No', 'NA', 'NA', 'Yes', 'Yes', 'Nothing', 'Yes', 'Yes', "Microphone doesn\\'t need access", 'I want to use a specific feature that requires this permission', 'Nothing bad will happen', "I don\\'t know", 'I have nothing to hide', 'I have nothing to hide', 'No', 'NA', 'No', 'NA', 'No', 'NA', 'No', 'NA', 'No', 'NA', '5,3,5,4,4,3,3,3,4', 'Yes', 'Microphone', 'Messenger I believe', 'They listen', 'Re-enabled the permission', '', '', '', '', '', '', '', '21-11-2017-05-20-41', '21-11-2017-05-27-59', '7.3']
# 5
# 5
# 65
# ['84512', 'CONTACTS', 'A1Q0N5H1DXMK0V', 'Android', 'Rarely', 'Agree', 'Male', 'High School', 'Black or African American', 'more than 18 months', 'Yes', 'Yes', 'By not checking the option in settings', 'Yes', 'Yes', 'Yes', 'I want to use a specific feature that requires this permission', 'I donâ€™t use the app', '', 'No', 'NA', 'NA', 'No', 'NA', 'NA', 'No', 'NA', 'NA', 'No', 'NA', 'NA', 'NA', 'NA', 'NA', "I didn\\'t know I did that", 'I trust the app developer', 'I trust the app developer', "I didn\\'t know I did that", 'NA', 'No', 'NA', 'No', 'NA', 'No', 'NA', 'No', 'NA', 'No', 'NA', '4,2,3,4,2,4,3,3,3', 'No', 'NA', 'NA', 'NA', 'NA', '', '', '', '', '', '', '', '21-11-2017-08-08-31', '21-11-2017-08-12-31', '4']
# 5
# 5
# 65
# ['78955', 'CAMERA', 'A1DBQJRBP7P9RX', 'Android', 'Rarely', 'Agree', 'Male', "Master\\'s or Professional degree (e.g. Law, Medical, Business, etc.)", 'Asian', '7-12 months', 'Yes', 'Yes', 'the app section in settings', 'Yes', 'Yes', 'NA', 'NA', 'NA', '', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', '2,4,2,3,3,4,3,4,4', 'No', 'NA', 'NA', 'NA', 'NA', '', '', '', '', '', '', '', '21-11-2017-08-30-29', '21-11-2017-08-33-40', '3.1833333333333']
# 5
# 5
# 65
# ['34674', 'STORAGE', 'A3B9M6H2PTCQWX', 'Android', 'Rarely', 'Agree', 'Male', 'Some college', 'White', '0-6 months', 'Yes', 'Yes', 'through the settings menu under apps', 'Yes', 'Yes', 'Yes', 'I want to use a specific feature that requires this permission', 'I donâ€™t use the app', '', 'Yes', 'No', 'NA', 'No', 'NA', 'NA', 'No', 'NA', 'NA', 'No', 'NA', 'NA', 'No', 'NA', 'NA', 'I want to use a specific feature that requires this permission', 'I want to use a specific feature that requires this permission', 'I want to use a specific feature that requires this permission', 'I want to use a specific feature that requires this permission', 'I want to use a specific feature that requires this permission', 'No', 'NA', 'No', 'NA', 'No', 'NA', 'No', 'NA', 'No', 'NA', '3,4,3,4,4,2,3,2,4', 'Yes', 'I donâ€™t remember', 'nfl prime time', "I didn\\'t want the app, it was bloatware that came with the device.", 'Uninstalled the app', '', '', '', '', '', '', '', '21-11-2017-11-03-44', '21-11-2017-11-09-55', '6.1833333333333']
# 5
# 5
# 65
# ['85129', 'PHONE', 'A1YM0IWPC72J7V', 'Android', 'Rarely', 'Agree', 'Male', 'College graduate (B.S., B.A., or other 4 year degree)', 'Asian', '0-6 months', 'Yes', 'Yes', 'go to app settings and deny permission', 'Yes', 'Yes', 'NA', 'NA', 'I expect the app will still work without this permission, I donâ€™t use the app', '', 'No', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'I have nothing to hide', 'NA', 'NA', 'NA', 'NA', 'Yes', 'I can always grant it afterwards if I change my mind, I donâ€™t use the app', 'Yes', "I think the app shouldn\\'t need this permission, I consider the permission to be very sensitive, I can always grant it afterwards if I change my mind", 'Yes', 'I can always grant it afterwards if I change my mind, I donâ€™t use the app', 'Yes', 'I expect the app will still work without this permission, I can always grant it afterwards if I change my mind', 'Yes', 'I can always grant it afterwards if I change my mind', '2,4,5,2,4,5,2,4,4', 'No', 'NA', 'NA', 'NA', 'NA', '', '', '', '', '', '', '', '22-11-2017-03-44-30', '22-11-2017-03-48-15', '3.75']
# 5
# 5
# 65
# ['87116', 'MICROPHONE', 'A1HUWK2J3GF1OY', 'Android', 'Rarely', 'Agree', 'Male', 'High School', 'White', '13-18 months', 'Yes', 'No', 'NA', 'NA', 'Yes', 'Yes', 'I want to use a specific feature that requires this permission, I have nothing to hide', 'I donâ€™t use the app', '4,4,4', 'No', 'NA', 'NA', 'No', 'NA', 'NA', 'No', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'I want to use a specific feature that requires this permission, I trust the app developer', 'I want to use a specific feature that requires this permission, I trust the app developer', 'I want to use a specific feature that requires this permission, I trust the app developer', 'NA', 'NA', 'Yes', 'I can always grant it afterwards if I change my mind', 'Yes', 'I can always grant it afterwards if I change my mind', 'Yes', 'I expect the app will still work without this permission, I can always grant it afterwards if I change my mind', 'Yes', 'I can always grant it afterwards if I change my mind', 'No', 'NA', '2,3,4,3,4,2,2,3,2', 'No', 'NA', 'NA', 'NA', 'NA', '', '', '', '', '', '', '', '22-11-2017-04-41-52', '22-11-2017-04-45-37', '3.75']
# 5
# 5
# 65
# ['63825', 'LOCATION', 'AXT49VCFZDGW8', 'Android', 'Rarely', 'Agree', 'Female', 'College graduate (B.S., B.A., or other 4 year degree)', 'White', 'more than 18 months', 'Yes', 'Yes', 'through the settings option', 'Yes', 'Yes', 'No', "I think the app won\\'t work otherwise, I wanted the permission screen to go away, I don\\'t know", 'The app did not ask for that permission/I did not disable the permission/I think thatâ€™s the default setting', '', 'No', 'NA', 'NA', 'Yes', 'Yes', 'app would have told me i needed to have it enabled', 'No', 'NA', 'NA', 'No', 'NA', 'NA', 'No', 'NA', 'NA', 'I want to use a specific feature that requires this permission, I have nothing to hide, Nothing bad will happen', "I think the app won\\'t work otherwise, I wanted the permission screen to go away, The app developer already has this information about me", 'I trust the app developer, I have nothing to hide, Nothing bad will happen', 'I want to use a specific feature that requires this permission, I trust the app developer, Because the app is popular, I have nothing to hide, Nothing bad will happen', "I want to use a specific feature that requires this permission, I think the app won\\'t work otherwise, I trust the app developer, Because the app is popular, I have nothing to hide, Nothing bad will happen", 'No', 'NA', 'Yes', "I think the app shouldn\\'t need this permission, I wanted the permission screen to go away", 'Yes', "I think the app shouldn\\'t need this permission, I expect the app will still work without this permission", 'No', 'NA', 'Yes', "I think the app shouldn\\'t need this permission, I expect the app will still work without this permission", '2,2,2,2,0,1,5,2,4', 'Yes', 'Location', 'snapchat', 'i couldnt use specific filters', 'Re-enabled the permission', '', '', '', '', '', '', '', '22-11-2017-03-36-59', '22-11-2017-03-49-39', '12.666666666667']
# 5
# 5
# 65
# ['37438', 'CAMERA', 'A1L3937MY09J3I', 'Android', 'Rarely', 'Agree', 'Male', 'College graduate (B.S., B.A., or other 4 year degree)', 'White', 'more than 18 months', 'Yes', 'Yes', 'apps access menu', 'Yes', 'Yes', 'Yes', 'Other: needed to in order to install', 'I donâ€™t use the app', '', 'Yes', 'No', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'Other: in order to upload pictures directly', 'NA', 'NA', 'NA', 'NA', 'Yes', 'The app did not ask for that permission/I did not disable the permission/I think thatâ€™s the default setting', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', '3,4,3,3,4,3,3,3,3', 'No', 'NA', 'NA', 'NA', 'NA', '', '', '', '', '', '', '', '22-11-2017-06-38-14', '22-11-2017-06-42-22', '4.1333333333333']
# 5
# 5
# 65
# ['60665', 'CONTACTS', 'A94DL4GI8ZBUO', 'Android', 'Rarely', 'Agree', 'Male', 'College graduate (B.S., B.A., or other 4 year degree)', 'White', '13-18 months', 'Yes', 'Yes', 'I would go to the user app setting and change it there.', 'No', 'Yes', 'Yes', 'I trust the app developer, Nothing bad will happen', "I didn\\'t know I did that", '', 'No', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'I trust the app developer', 'NA', 'NA', 'NA', 'NA', 'No', 'NA', 'No', 'NA', 'No', 'NA', 'No', 'NA', 'No', 'NA', '2,2,1,3,2,4,2,2,3', 'No', 'NA', 'NA', 'NA', 'NA', '', '', '', '', '', '', '', '22-11-2017-06-36-53', '22-11-2017-06-40-01', '3.1333333333333']
# 5
# 5
# 65
# ['50359', 'STORAGE', 'A1TARNH07A75CG', 'Android', 'Rarely', 'Agree', 'Male', 'College graduate (B.S., B.A., or other 4 year degree)', 'Black or African American', '0-6 months', 'No', 'Yes', 'the specific app settings', '', 'No', 'No', "I didn\\'t know I did that", "I don\\'t know", '3', 'No', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', "I don\\'t know", 'NA', 'NA', 'NA', 'NA', 'No', 'NA', 'No', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', '3,3,5,3,3,3,1,3,3', 'No', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', '20-02-2018-10-59-16', '20-02-2018-11-03-19', '4.05']
# 5
# 5
# 65
# ['19339', 'CONTACTS', 'A3DFJV1RD653DQ', 'Android', 'Rarely', 'Agree', 'Male', 'Some college', 'Black or African American', '7-12 months', 'Yes', 'Yes', 'Go to permissions', 'Yes', 'Yes', 'Yes', "I think the app won\\'t work otherwise, I want to use a specific feature that requires this permission", 'The app did not ask for that permission/I did not disable the permission/I think thatâ€™s the default setting', '4,4,5,3,4', 'No', 'NA', 'NA', 'No', 'NA', 'NA', 'Yes', 'No', 'NA', 'No', 'NA', 'NA', 'No', 'NA', 'NA', 'The app developer already has this information about me', 'I trust the app developer', 'I have nothing to hide', "I don\\'t know", 'I have nothing to hide, Nothing bad will happen', 'No', 'NA', 'Yes', "I can always grant it afterwards if I change my mind, I expect the app will still work without this permission, I think the app shouldn\\'t need this permission", 'No', 'NA', 'No', 'NA', 'No', 'NA', '4,3,4,4,4,3,2,2,4', 'No', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', '20-02-2018-11-14-08', '20-02-2018-11-23-07', '8.9833333333333']
# 5
# 5
# 65
# ['73365', 'CAMERA', 'A3LIOY7C4ZDQ50', 'Android', 'Rarely', 'Agree', 'Male', 'High School', 'White', '0-6 months', 'Yes', 'Yes', "In the Settings app there\\'s an App Permissions menu. I would select the app and toggle permissions I want to allow or deny.", 'Yes', 'Yes', 'Yes', "I trust the app developer, I think the app won\\'t work otherwise, Nothing bad will happen", 'I donâ€™t use the app, I can always grant it afterwards if I change my mind', '5', 'No', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', "I think the app won\\'t work otherwise, I trust the app developer", 'NA', 'NA', 'NA', 'NA', 'Yes', "I think the app shouldn\\'t need this permission, I can always grant it afterwards if I change my mind, I don\\'t trust the developer enough to provide this information, I expect the app will still work without this permission", 'Yes', "I think the app shouldn\\'t need this permission, I can always grant it afterwards if I change my mind, I expect the app will still work without this permission", 'Yes', "I think the app shouldn\\'t need this permission, I expect the app will still work without this permission, I can always grant it afterwards if I change my mind", 'Yes', 'I do not use the specific feature associated with the permission, I can always grant it afterwards if I change my mind', 'Yes', 'I do not use the specific feature associated with the permission, I can always grant it afterwards if I change my mind', '4,5,4,5,4,3,3,2,5', 'No', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', '20-02-2018-10-45-52', '20-02-2018-10-55-33', '9.6833333333333']
# 5
# 5
# 65
# ['69196', 'MICROPHONE', 'A2HHKBW8HQWI66', 'Android', 'Rarely', 'Agree', 'Male', 'College graduate (B.S., B.A., or other 4 year degree)', 'White', 'more than 18 months', 'Yes', 'Yes', 'app permissions under settings', 'Yes', 'Yes', 'Yes', 'I want to use a specific feature that requires this permission', 'I donâ€™t use the app', '5,5,5', 'No', 'NA', 'NA', 'No', 'NA', 'NA', 'No', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'I want to use a specific feature that requires this permission', 'I want to use a specific feature that requires this permission', 'I want to use a specific feature that requires this permission', 'NA', 'NA', 'Yes', 'I do not use the specific feature associated with the permission, I can always grant it afterwards if I change my mind, I donâ€™t use the app', 'Yes', "I do not use the specific feature associated with the permission, I don\\'t trust the developer enough to provide this information", 'No', 'NA', 'Yes', 'I expect the app will still work without this permission', 'Yes', 'I do not use the specific feature associated with the permission, I expect the app will still work without this permission', '4,4,4,5,5,2,2,2,5', 'No', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', '20-02-2018-10-47-22', '20-02-2018-10-51-55', '4.55']
# 5
# 5
# 65
# ['83419', 'MICROPHONE', 'A1TTFE7OTLIJW8', 'Android', 'Rarely', 'Agree', 'Male', "Master\\'s or Professional degree (e.g. Law, Medical, Business, etc.)", 'White', '13-18 months', 'Yes', 'Yes', 'Go into settings, then app settings, and on the specific app change the setting there.', 'Yes', 'Yes', 'Yes', "Nothing bad will happen, I have nothing to hide, I want to use a specific feature that requires this permission, I think the app won\\'t work otherwise", "I do not use the specific feature associated with the permission, Other: I don\\'t use the app, so it hasn\\'t come up.", '5', 'No', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'I have nothing to hide', 'NA', 'NA', 'NA', 'NA', 'No', 'NA', 'No', 'NA', 'No', 'NA', 'No', 'NA', 'No', 'NA', '2,3,3,4,3,4,4,3,4', 'No', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', '20-02-2018-10-45-38', '20-02-2018-10-48-56', '3.3']
# 5
# 5
# 65
# ['62297', 'LOCATION', 'A23EWFNNOUS10B', 'Android', 'Rarely', 'Agree', 'Male', 'College graduate (B.S., B.A., or other 4 year degree)', 'White', '13-18 months', 'Yes', 'Yes', 'By going to the usage settings.', 'Yes', 'Yes', 'Yes', 'I trust the app developer', 'I can always grant it afterwards if I change my mind', '5,5,5,5,5', 'No', 'NA', 'NA', 'No', 'NA', 'NA', 'No', 'NA', 'NA', 'No', 'NA', 'NA', 'No', 'NA', 'NA', 'I want to use a specific feature that requires this permission', 'I trust the app developer', 'I want to use a specific feature that requires this permission', 'I trust the app developer', 'I want to use a specific feature that requires this permission', 'No', 'NA', 'No', 'NA', 'No', 'NA', 'No', 'NA', 'No', 'NA', '3,3,4,4,3,4,3,3,3', 'No', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', '20-02-2018-10-40-07', '20-02-2018-10-43-10', '3.05']
# 5
# 5
# 65
# ['38470', 'PHONE', 'A1MURUJBBDJWM6', 'Android', 'Rarely', 'Agree', 'Male', "Master\\'s or Professional degree (e.g. Law, Medical, Business, etc.)", 'White', 'more than 18 months', 'Yes', 'Yes', 'Go into settings and look around for it somewhere.', 'Yes', 'Yes', 'Yes', "I think the app won\\'t work otherwise", 'I expect the app will still work without this permission', '3,5,5,5,5', 'No', 'NA', 'NA', 'No', 'NA', 'NA', 'Yes', 'No', 'NA', 'No', 'NA', 'NA', 'No', 'NA', 'NA', 'I trust the app developer, I have nothing to hide', 'I want to use a specific feature that requires this permission', 'I want to use a specific feature that requires this permission', "I didn\\'t know I did that", "I trust the app developer, I didn\\'t know I did that", 'No', 'NA', 'No', 'NA', 'No', 'NA', 'No', 'NA', 'No', 'NA', '3,3,2,3,3,3,2,3,3', 'Yes', 'Location', 'I believe i had had issues with facebook in the past', 'Many services are location based', 'Re-enabled the permission', 'I permanently enabled the permission for the app and never disabled it again', 'agree', 'No', 'NA', 'NA', 'NA', 'NA', '19-02-2018-07-21-10', '19-02-2018-07-25-38', '4.4666666666667']
# 5
# 5
# 65
# ['92776', 'LOCATION', 'A3ANNQ73J8M158', 'Android', 'Rarely', 'Agree', 'Female', 'High School', 'White', '13-18 months', 'Yes', 'Yes', 'go into settings and mess with permissions', 'Yes', 'Yes', 'Yes', 'I trust the app developer', 'I donâ€™t use the app', '5,5', 'No', 'NA', 'NA', 'No', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'I have nothing to hide, I trust the app developer', 'I trust the app developer', 'NA', 'NA', 'NA', 'Yes', 'I donâ€™t use the app', 'Yes', 'I expect the app will still work without this permission', 'Yes', 'I wanted the permission screen to go away', 'Yes', 'I do not use the specific feature associated with the permission', 'Yes', 'I can always grant it afterwards if I change my mind', '4,3,1,3,2,3,2,2,1', 'No', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', '19-02-2018-04-41-48', '19-02-2018-04-44-36', '2.8']
# 5
# 5
# 65
# ['14068', 'MICROPHONE', 'A1W7QLLENVP2AE', 'Android', 'Rarely', 'Agree', 'Male', 'College graduate (B.S., B.A., or other 4 year degree)', 'White', 'more than 18 months', 'Yes', 'Yes', 'Through the permissions or by uninstalling', 'Yes', 'Yes', 'Yes', 'I want to use a specific feature that requires this permission', 'I expect the app will still work without this permission', '5,5,5,5,5', 'No', 'NA', 'NA', 'No', 'NA', 'NA', 'No', 'NA', 'NA', 'No', 'NA', 'NA', 'No', 'NA', 'NA', "I didn\\'t know I did that", 'I want to use a specific feature that requires this permission', 'I want to use a specific feature that requires this permission', 'I want to use a specific feature that requires this permission', 'I trust the app developer', 'No', 'NA', 'No', 'NA', 'No', 'NA', 'No', 'NA', 'NA', 'NA', '3,4,2,2,3,3,3,3,3', 'Yes', 'Location', 'Google Maps', "It didn\\'t register", 'Re-enabled the permission', 'I permanently enabled the permission for the app and never disabled it again', 'agree', 'No', 'NA', 'NA', 'NA', 'NA', '19-02-2018-04-57-59', '19-02-2018-05-02-36', '4.6166666666667']
# 5
# 5
# 65
# ['21222', 'LOCATION', 'A3774HPOUKYTX7', 'Android', 'Rarely', 'Agree', 'Male', 'College graduate (B.S., B.A., or other 4 year degree)', 'White', 'more than 18 months', 'Yes', 'Yes', 'usage settings', 'Yes', 'Yes', 'Yes', 'I want to use a specific feature that requires this permission, I trust the app developer', "I think the app shouldn\\'t need this permission, I consider the permission to be very sensitive", '5,5,5,5,5', 'No', 'NA', 'NA', 'No', 'NA', 'NA', 'No', 'NA', 'NA', 'No', 'NA', 'NA', 'No', 'NA', 'NA', 'I want to use a specific feature that requires this permission', "I think the app won\\'t work otherwise", "I think the app won\\'t work otherwise", "I want to use a specific feature that requires this permission, I won\\'t be able to grant this permission later", 'I trust the app developer', 'No', 'NA', 'No', 'NA', 'No', 'NA', 'No', 'NA', 'No', 'NA', '3,4,4,3,4,3,5,4,3', 'No', 'NA', 'NA', 'NA', 'NA', '', '', '', '', '', '', '', '11-01-2018-02-10-27', '11-01-2018-02-13-40', '3.2166666666667']
# 5
# 5
# 65
# ['75998', 'LOCATION', 'A1N9WMQ23RWU9Q', 'Android', 'Rarely', 'Agree', 'Female', 'College graduate (B.S., B.A., or other 4 year degree)', 'Hispanic', '0-6 months', 'Yes', 'Yes', 'Usually going to the app in settings, I think.', 'Yes', 'Yes', 'Yes', "I want to use a specific feature that requires this permission, I think the app won\\'t work otherwise", 'I donâ€™t use the app', '4,4,4,4,4', 'No', 'NA', 'NA', 'No', 'NA', 'NA', 'No', 'NA', 'NA', 'No', 'NA', 'NA', 'No', 'NA', 'NA', "I want to use a specific feature that requires this permission, I think the app won\\'t work otherwise", "I want to use a specific feature that requires this permission, I think the app won\\'t work otherwise", "I think the app won\\'t work otherwise", 'I want to use a specific feature that requires this permission', 'I want to use a specific feature that requires this permission', 'No', 'NA', 'No', 'NA', 'No', 'NA', 'No', 'NA', 'No', 'NA', '3,3,2,3,2,2,2,2,2', 'Yes', 'I donâ€™t remember', "There were some but I really can\\'t recall right now.", "The problem I usually encounter is that if I don\\'t give the app access to what it asks, it won\\'t work. I can\\'t remember which apps gave me this issue, but it has happened in the past more than once. More than a few times, in fact.", 'Re-enabled the permission', '', '', '', '', '', '', '', '11-01-2018-07-10-22', '11-01-2018-07-23-15', '12.883333333333']
# 5
# 5
# 65
# ['98471', 'CONTACTS', 'A33S9Z0SQC71A0', 'Android', 'Rarely', 'Agree', 'Male', 'Some college', 'White', '13-18 months', 'Yes', 'Yes', 'id google it first then follow directions i find.', 'No', 'Yes', 'Yes', "I don\\'t know", 'I donâ€™t use the app', '3,3,3', 'No', 'NA', 'NA', 'No', 'NA', 'NA', 'No', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', "I don\\'t know", "I don\\'t know", "I don\\'t know", 'NA', 'NA', 'No', 'NA', 'No', 'NA', 'No', 'NA', 'No', 'NA', 'No', 'NA', '4,4,4,4,4,4,4,4,4', 'No', 'NA', 'NA', 'NA', 'NA', '', '', '', '', '', '', '', '11-01-2018-10-19-51', '11-01-2018-10-24-08', '4.2833333333333']
# 5
# 5
# 65
# ['56168', 'CAMERA', 'A1DS5O8MSI3ZH0', 'Android', 'Rarely', 'Agree', 'Male', 'College graduate (B.S., B.A., or other 4 year degree)', 'White', '0-6 months', 'Yes', 'Yes', 'go into settings, then apps, the to the app I want to change, then change the sttings', 'Yes', 'Yes', 'Yes', 'I want to use a specific feature that requires this permission, I trust the app developer, I have nothing to hide, Nothing bad will happen', "I think the app shouldn\\'t need this permission, I expect the app will still work without this permission, I consider the permission to be very sensitive", '4,4,4,4,4', 'No', 'NA', 'NA', 'No', 'NA', 'NA', 'No', 'NA', 'NA', 'Yes', 'No', 'NA', 'No', 'NA', 'NA', 'I want to use a specific feature that requires this permission', 'I want to use a specific feature that requires this permission, I trust the app developer', 'I want to use a specific feature that requires this permission', 'I want to use a specific feature that requires this permission, I trust the app developer', "I want to use a specific feature that requires this permission, I think the app won\\'t work otherwise, I trust the app developer", 'No', 'NA', 'No', 'NA', 'No', 'NA', 'No', 'NA', 'No', 'NA', '2,3,2,4,4,4,3,4,4', "I don\\'t know", 'I donâ€™t remember', "I don\\'t know", "I don\\'t recall", 'Re-enabled the permission', '', '', '', '', '', '', '', '11-01-2018-01-10-25', '11-01-2018-01-15-19', '4.9']
# 5
# 5
# 65
# ['58714', 'PHONE', 'APY5858P6BTDY', 'Android', 'Rarely', 'Agree', 'Would prefer not to answer', 'Would prefer not to answer', 'Would prefer not to answer', '0-6 months', 'Yes', 'Yes', 'go to permissions', 'No', 'Yes', 'No', "I want to use a specific feature that requires this permission, I think the app won\\'t work otherwise", 'I donâ€™t use the app', '4,4', 'Yes', 'No', 'NA', 'No', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'I want to use a specific feature that requires this permission', 'I want to use a specific feature that requires this permission', 'NA', 'NA', 'NA', 'No', 'NA', 'No', 'NA', 'No', 'NA', 'No', 'NA', 'No', 'NA', '3,4,4,3,4,3,4,4,4', "I don\\'t know", 'I donâ€™t remember', 'simple', "I don\\'t remember", 'Nothing', '', '', '', '', '', '', '', '12-01-2018-12-56-56', '12-01-2018-01-01-03', '4.1166666666667']
# 5
# 5
# 65
# ['39504', 'PHONE', 'A20MYUKGSXUKM7', 'Android', 'Rarely', 'Agree', 'Male', 'High School', 'White', '0-6 months', 'Yes', 'Yes', 'I would go into the privacy settings of an app and change the information of what the apps does and collects.', 'No', 'Yes', 'Yes', 'I wanted the permission screen to go away, I have nothing to hide', "I didn\\'t know I did that", '5,5', 'No', 'NA', 'NA', 'No', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'I have nothing to hide', "I think the app won\\'t work otherwise", 'NA', 'NA', 'NA', 'No', 'NA', 'No', 'NA', 'No', 'NA', 'No', 'NA', 'No', 'NA', '2,2,2,2,2,2,2,2,2', 'No', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', '19-02-2018-07-18-59', '19-02-2018-07-22-59', '4']
# 5
# 5
# 65
# ['76054', 'CAMERA', 'AB7LYMORLR5H0', 'Android', 'Rarely', 'Agree', 'Female', 'College graduate (B.S., B.A., or other 4 year degree)', 'Black or African American', '7-12 months', 'Yes', 'Yes', 'I hope to settings then permissions', 'No', 'No', 'Yes', "I don\\'t know", 'The app did not ask for that permission/I did not disable the permission/I think thatâ€™s the default setting', '4,4,4', 'No', 'NA', 'NA', 'No', 'NA', 'NA', 'No', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'I want to use a specific feature that requires this permission', 'I want to use a specific feature that requires this permission', 'I want to use a specific feature that requires this permission', 'NA', 'NA', 'No', 'NA', 'No', 'NA', 'No', 'NA', 'No', 'NA', 'No', 'NA', '3,4,4,4,4,4,4,4,4', 'No', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', '20-02-2018-02-09-49', '20-02-2018-02-14-10', '4.35']
# 5
# 5
# 65
# ['78681', 'LOCATION', 'A37CO0N1KC1CDW', 'Android', 'Rarely', 'Agree', 'Female', 'Some college', 'White', 'more than 18 months', 'Yes', 'No', 'NA', 'NA', 'Yes', 'Yes', 'I trust the app developer', "I don\\'t trust the developer enough to provide this information", '3,4', 'No', 'NA', 'NA', 'Yes', 'Yes', 'none', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'Because the app is popular', 'I trust the app developer', 'NA', 'NA', 'NA', 'Yes', 'Other: ', 'Yes', "I think the app shouldn\\'t need this permission", 'Yes', 'The app did not ask for that permission/I did not disable the permission/I think thatâ€™s the default setting', 'NA', 'NA', 'NA', 'NA', '2,4,3,3,4,2,2,4,4', 'No', 'NA', 'NA', 'NA', 'NA', '', '', '', '', '', '', '', '12-01-2018-03-27-16', '12-01-2018-03-29-00', '1.7333333333333']
# 5
# 5
# 65
# ['56990', 'CAMERA', 'A1USR9JCAMDGM3', 'Android', 'Rarely', 'Agree', 'Female', 'High School', 'White', 'more than 18 months', 'Yes', 'No', 'NA', 'NA', 'Yes', 'Yes', 'I have nothing to hide', "I didn\\'t know I did that", '5,5', 'No', 'NA', 'NA', 'No', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'I want to use a specific feature that requires this permission', "I think the app won\\'t work otherwise", 'NA', 'NA', 'NA', 'Yes', 'I donâ€™t use the app', 'No', 'NA', 'No', 'NA', 'No', 'NA', 'No', 'NA', '4,4,4,4,4,4,4,4,4', 'No', 'NA', 'NA', 'NA', 'NA', '', '', '', '', '', '', '', '12-01-2018-08-31-49', '12-01-2018-08-36-07', '4.3']
# 5
# 5
# 65
# ['81290', 'CONTACTS', 'A1RDRK3QTM7U96', 'Android', 'Rarely', 'Agree', 'Female', 'College graduate (B.S., B.A., or other 4 year degree)', 'Hispanic', '13-18 months', 'Yes', 'Yes', 'I would access the usage setting and set it manually', 'Yes', 'Yes', 'Yes', "I think the app won\\'t work otherwise", 'I donâ€™t use the app', '4,5,4,3,4', 'No', 'NA', 'NA', 'No', 'NA', 'NA', 'Yes', 'No', 'NA', 'No', 'NA', 'NA', 'Yes', 'No', 'NA', 'I have nothing to hide', 'I trust the app developer', "I don\\'t know", 'The app developer already has this information about me', 'I have nothing to hide', 'No', 'NA', 'No', 'NA', 'No', 'NA', 'No', 'NA', 'No', 'NA', '3,5,5,4,3,5,5,5,4', 'No', 'NA', 'NA', 'NA', 'NA', '', '', '', '', '', '', '', '12-01-2018-09-53-52', '12-01-2018-09-59-06', '5.2333333333333']
# 5
# 5
# 65
# ['21258', 'PHONE', 'AF9NBMEJ385W9', 'Android', 'Rarely', 'Agree', 'Female', 'Other: Associates', 'Black or African American', 'more than 18 months', 'Yes', 'Yes', 'By going in my settings and going to security and changing the access to no.', 'No', 'Yes', 'No', "I don\\'t know, Because the app is popular, I think the app won\\'t work otherwise", "I didn\\'t know I did that", '4,4,4,4,4', 'No', 'NA', 'NA', 'No', 'NA', 'NA', 'No', 'NA', 'NA', 'Yes', 'No', 'NA', 'No', 'NA', 'NA', "I didn\\'t know I did that", "I didn\\'t know I did that", "I didn\\'t know I did that, I trust the app developer", "I didn\\'t know I did that, I trust the app developer, I think the app won\\'t work otherwise, Because the app is popular", "I didn\\'t know I did that", 'No', 'NA', 'No', 'NA', 'No', 'NA', 'No', 'NA', 'No', 'NA', '2,2,4,4,2,3,3,3,3', "I don\\'t know", 'I donâ€™t remember', 'Fit bit', "it wouldn\\'t sync correctly", 'Nothing', '', '', '', '', '', '', '', '12-01-2018-11-49-39', '12-01-2018-11-59-34', '9.9166666666667']
# 5
# 5
# 65
# ['12311', 'STORAGE', 'AEXF5EUX32U0M', 'Android', 'Rarely', 'Agree', 'Female', 'Some college', 'White', '7-12 months', 'Yes', 'Yes', 'in security settings', 'No', 'Yes', 'Yes', 'I have nothing to hide', "I don\\'t know, I didn\\'t know I did that", '4,4,4,4,4', 'No', 'NA', 'NA', 'No', 'NA', 'NA', 'No', 'NA', 'NA', 'No', 'NA', 'NA', 'No', 'NA', 'NA', 'I wanted the permission screen to go away', 'I wanted the permission screen to go away', 'Nothing bad will happen', 'I wanted the permission screen to go away', "I think the app won\\'t work otherwise", 'No', 'NA', 'No', 'NA', 'No', 'NA', 'NA', 'NA', 'NA', 'NA', '1,1,1,1,1,1,1,1,1', 'No', 'NA', 'NA', 'NA', 'NA', '', '', '', '', '', '', '', '13-01-2018-05-51-54', '13-01-2018-05-55-45', '3.85']
# 5
# 5
# 65
# ['44542', 'LOCATION', 'A3VIQ9XPOYB8K6', 'Android', 'Rarely', 'Agree', 'Female', 'Some college', 'White', '13-18 months', 'Yes', 'Yes', 'privacy settings', 'No', 'Yes', 'Yes', "I think the app won\\'t work otherwise", 'I donâ€™t use the app', '1,1,1,1,4', 'No', 'NA', 'NA', 'No', 'NA', 'NA', 'No', 'NA', 'NA', 'No', 'NA', 'NA', 'No', 'NA', 'NA', "I didn\\'t know I did that", "I didn\\'t know I did that", "I didn\\'t know I did that", "I didn\\'t know I did that", 'I trust the app developer', 'No', 'NA', 'No', 'NA', 'No', 'NA', 'No', 'NA', 'No', 'NA', '5,5,5,3,4,2,3,2,4', 'Yes', 'Camera', 'dont recall', "i couldn\\'t access it unless i gave it access", 'Uninstalled the app', '', '', '', '', '', '', '', '26-01-2018-04-49-07', '26-01-2018-04-55-04', '5.95']
# 5
# 5
# 65
# ['90699', 'MICROPHONE', 'A3B7TNVOISSZ2O', 'Android', 'Rarely', 'Agree', 'Male', "Master\\'s or Professional degree (e.g. Law, Medical, Business, etc.)", 'White', 'more than 18 months', 'Yes', 'Yes', 'Go into app manager, I think', 'Yes', 'Yes', 'Yes', 'I trust the app developer, I have nothing to hide', 'I donâ€™t use the app', '5,5,5,5', 'No', 'NA', 'NA', 'No', 'NA', 'NA', 'Yes', 'No', 'NA', 'Yes', 'Yes', "There wasn\\'t one", 'NA', 'NA', 'NA', 'I trust the app developer', 'I have nothing to hide, I trust the app developer', 'I trust the app developer, I have nothing to hide', "I didn\\'t know I did that", 'NA', 'No', 'NA', 'No', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', '2,4,3,4,4,2,4,2,4', 'No', 'NA', 'NA', 'NA', 'NA', '', '', '', '', '', '', '', '26-01-2018-11-48-32', '26-01-2018-11-52-49', '4.2833333333333']
# 5
# 5
# 65
# ['59438', 'CONTACTS', 'A110KENBXU7SUJ', 'Android', 'Rarely', 'Agree', 'Male', 'High School', 'White', '7-12 months', 'Yes', 'Yes', 'by going into the apps access and changing what it has the ability to do', 'Yes', 'Yes', 'Yes', 'I want to use a specific feature that requires this permission', 'I donâ€™t use the app', '3,4,4,3', 'No', 'NA', 'NA', 'No', 'NA', 'NA', 'No', 'NA', 'NA', 'No', 'NA', 'NA', 'NA', 'NA', 'NA', 'I want to use a specific feature that requires this permission', "I think the app won\\'t work otherwise", 'I want to use a specific feature that requires this permission', "I think the app won\\'t work otherwise", 'NA', 'No', 'NA', 'No', 'NA', 'Yes', "I think the app shouldn\\'t need this permission, I expect the app will still work without this permission", 'Yes', "I think the app shouldn\\'t need this permission", 'No', 'NA', '4,3,3,4,4,3,3,3,4', "I don\\'t know", 'I donâ€™t remember', "I don\\'t remember", "I don\\'t recall what the problem was", 'Nothing', '', '', '', '', '', '', '', '26-01-2018-01-42-09', '26-01-2018-01-47-18', '5.15']
# 5
# 5
# 65
# ['33867', 'CAMERA', 'A2JCHN90PRUWDH', 'Android', 'Rarely', 'Agree', 'Male', 'Some college', 'White', '7-12 months', 'Yes', 'No', 'NA', 'NA', 'No', 'Yes', 'I want to use a specific feature that requires this permission', 'The app did not ask for that permission/I did not disable the permission/I think thatâ€™s the default setting', '4,4', 'Yes', 'No', 'NA', 'No', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'Nothing bad will happen', "I think the app won\\'t work otherwise", 'NA', 'NA', 'NA', 'No', 'NA', 'No', 'NA', 'No', 'NA', 'NA', 'NA', 'NA', 'NA', '2,2,2,2,2,2,2,0,2', 'No', 'NA', 'NA', 'NA', 'NA', '', '', '', '', '', '', '', '26-01-2018-12-37-20', '26-01-2018-12-43-23', '6.05']
# 5
# 5
# 65
# ['63086', 'PHONE', 'A9WIOFVRSYW3L', 'Android', 'Rarely', 'Agree', 'Female', 'Doctoral degree', 'White', '7-12 months', 'Yes', 'Yes', 'in the settings I would find apps, and found permissions of the app. then I would unclick what I do not want them to collect.', 'No', 'Yes', 'Yes', "The app developer already has this information about me, I trust the app developer, I think the app won\\'t work otherwise, I want to use a specific feature that requires this permission", 'I think something bad might happen if I provide this permission, I expect the app will still work without this permission', '1', 'Yes', 'Yes', 'I use viber only to contact my sister living abroad. otherwise I always disable this app. I think they collect too much info...', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', "I didn\\'t know I did that", 'NA', 'NA', 'NA', 'NA', 'No', 'NA', 'No', 'NA', 'No', 'NA', 'No', 'NA', 'No', 'NA', '4,2,4,2,4,4,3,3,3', 'No', 'NA', 'NA', 'NA', 'NA', '', '', '', '', '', '', '', '26-01-2018-01-46-26', '26-01-2018-01-53-03', '6.6166666666667']
# 5
# 5
# 65
# ['75256', 'STORAGE', 'A3QPVH0DRW0ZQV', 'Android', 'Rarely', 'Agree', 'Female', 'High School', 'White', 'more than 18 months', 'Yes', 'Yes', 'change options under app permissions', 'Yes', 'Yes', 'Yes', 'I trust the app developer, I want to use a specific feature that requires this permission', 'I donâ€™t use the app', '5,5,5,5,5', 'No', 'NA', 'NA', 'No', 'NA', 'NA', 'No', 'NA', 'NA', 'No', 'NA', 'NA', 'No', 'NA', 'NA', "I trust the app developer, I think the app won\\'t work otherwise", "I think the app won\\'t work otherwise, I want to use a specific feature that requires this permission", "I didn\\'t know I did that", "I think the app won\\'t work otherwise, I want to use a specific feature that requires this permission", "I didn\\'t know I did that", 'No', 'NA', 'No', 'NA', 'Yes', "I think the app shouldn\\'t need this permission", 'Yes', "I don\\'t trust the developer enough to provide this information", 'No', 'NA', '4,4,4,4,4,4,4,4,4', 'Yes', 'Camera', 'QR Reader', 'It needed to see the actual QR code to read it', 'Re-enabled the permission', '', '', '', '', '', '', '', '26-01-2018-03-20-37', '26-01-2018-03-28-37', '8']
# 5
# 5
# 65
# ['57847', 'STORAGE', 'A1601UNFFAAQOI', 'Android', 'Rarely', 'Agree', 'Female', 'College graduate (B.S., B.A., or other 4 year degree)', 'Black or African American', '7-12 months', 'Yes', 'Yes', 'Access app permissions in settings', 'No', 'Yes', 'No', 'Other: App was default on device and I never reviewed its permissions', 'I think something bad might happen if I provide this permission', '5,5,5,5,5', 'No', 'NA', 'NA', 'No', 'NA', 'NA', 'No', 'NA', 'NA', 'No', 'NA', 'NA', 'No', 'NA', 'NA', "I think the app won\\'t work otherwise", "I think the app won\\'t work otherwise", "I think the app won\\'t work otherwise", "I think the app won\\'t work otherwise", "I think the app won\\'t work otherwise", 'No', 'NA', 'No', 'NA', 'No', 'NA', 'No', 'NA', 'No', 'NA', '3,4,3,4,3,3,3,2,4', 'Yes', 'Location', 'It was a photo printing app that would not function without location services so I uninstalled it (apologies, cannot remember exact name)', "Kept prompting for location services, which I didn\\'t see as necessary and try to keep off as much as possible", 'Uninstalled the app', '', '', '', '', '', '', '', '26-01-2018-02-56-36', '26-01-2018-03-37-45', '41.15']
# 5
# 5
# 65
# ['38993', 'LOCATION', 'A12MV66U9VGLQ1', 'Android', 'Rarely', 'Agree', 'Female', 'College graduate (B.S., B.A., or other 4 year degree)', 'White', '0-6 months', 'Yes', 'No', 'NA', 'NA', 'Yes', 'No', "I didn\\'t know I did that", "I didn\\'t know I did that", '5,3,5,3,5', 'No', 'NA', 'NA', 'No', 'NA', 'NA', 'No', 'NA', 'NA', 'No', 'NA', 'NA', 'No', 'NA', 'NA', "I didn\\'t know I did that", 'I want to use a specific feature that requires this permission', 'I want to use a specific feature that requires this permission', "I didn\\'t know I did that", 'I want to use a specific feature that requires this permission', 'No', 'NA', 'No', 'NA', 'No', 'NA', 'No', 'NA', 'No', 'NA', '3,3,5,5,5,5,5,5,5', 'Yes', 'I donâ€™t remember', "Don\\'t know..just remember that I couldn\\'t continue install", "I just didn\\'t want to allow the new app those permissions so couldn\\'t comp late installation", 'Re-enabled the permission', '', '', '', '', '', '', '', '26-01-2018-04-18-56', '26-01-2018-04-29-46', '10.833333333333']
# 5
# 5
# 65
# ['50102', 'MICROPHONE', 'A1JO6AY55FG7QU', 'Android', 'Rarely', 'Agree', 'Female', 'College graduate (B.S., B.A., or other 4 year degree)', 'White', '13-18 months', 'Yes', 'Yes', 'going under settings and security on my phone', 'Yes', 'Yes', 'Yes', 'Nothing bad will happen', 'I can always grant it afterwards if I change my mind', '5,5,5,5,5', 'No', 'NA', 'NA', 'No', 'NA', 'NA', 'No', 'NA', 'NA', 'No', 'NA', 'NA', 'No', 'NA', 'NA', "I didn\\'t know I did that", "I think the app won\\'t work otherwise, I trust the app developer, I want to use a specific feature that requires this permission", 'I have nothing to hide', "I think the app won\\'t work otherwise, I want to use a specific feature that requires this permission, I trust the app developer", 'I trust the app developer', 'No', 'NA', 'No', 'NA', 'No', 'NA', 'No', 'NA', 'No', 'NA', '1,3,3,3,3,3,1,1,2', 'No', 'NA', 'NA', 'NA', 'NA', '', '', '', '', '', '', '', '28-01-2018-10-33-22', '28-01-2018-10-39-48', '6.4333333333333']
# 5
# 5
# 65
# ['90799', 'CONTACTS', 'A1NSWJKFJIZ06J', 'Android', 'Rarely', 'Agree', 'Male', 'College graduate (B.S., B.A., or other 4 year degree)', 'Asian', 'more than 18 months', 'Yes', 'Yes', 'I would go to settings and application preferences', 'Yes', 'Yes', 'No', 'I want to use a specific feature that requires this permission', "I think the app shouldn\\'t need this permission", '2,2,4,2,2', 'No', 'NA', 'NA', 'No', 'NA', 'NA', 'No', 'NA', 'NA', 'Yes', 'No', 'NA', 'Yes', 'No', 'NA', "I didn\\'t know I did that", "I didn\\'t know I did that", "I think the app won\\'t work otherwise", "I don\\'t know", "I don\\'t know", 'No', 'NA', 'No', 'NA', 'No', 'NA', 'No', 'NA', 'No', 'NA', '4,4,4,4,4,4,4,4,4', 'No', 'NA', 'NA', 'NA', 'NA', '', '', '', '', '', '', '', '28-01-2018-11-04-34', '28-01-2018-11-08-26', '3.8666666666667']
# 5
# 5
# 65
# ['41842', 'CAMERA', 'A5X1KZ9CCHREK', 'Android', 'Rarely', 'Agree', 'Male', 'Some college', 'White', 'more than 18 months', 'Yes', 'Yes', 'go to app permission and change it', 'Yes', 'Yes', 'Yes', 'I have nothing to hide, Because the app is popular, I trust the app developer', "I think the app shouldn\\'t need this permission, I don\\'t trust the developer enough to provide this information", '5', 'No', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'I trust the app developer, I have nothing to hide, Because the app is popular, Nothing bad will happen', 'NA', 'NA', 'NA', 'NA', 'Yes', 'I consider the permission to be very sensitive, I wanted to test whether the app will work without the permission', 'No', 'NA', 'Yes', "I don\\'t trust the developer enough to provide this information, I consider the permission to be very sensitive, I expect the app will still work without this permission", 'NA', 'NA', 'NA', 'NA', '5,5,5,4,4,5,2,4,3', "I don\\'t know", 'Contacts', "i don\\'t remember", "It don\\'t let me use the app", 'Re-enabled the permission', '', '', '', '', '', '', '', '29-01-2018-12-50-03', '29-01-2018-12-54-59', '4.9333333333333']
# 5
# 5
# 65
# ['13508', 'CAMERA', 'A1M682B2WUSYJP', 'Android', 'Rarely', 'Agree', 'Male', 'College graduate (B.S., B.A., or other 4 year degree)', 'White', '13-18 months', 'Yes', 'Yes', 'App settings, then that app, then permissions.', 'Yes', 'Yes', 'Yes', 'I trust the app developer, I want to use a specific feature that requires this permission', 'I can always grant it afterwards if I change my mind', '5,5,5', 'No', 'NA', 'NA', 'No', 'NA', 'NA', 'No', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'I want to use a specific feature that requires this permission', 'I want to use a specific feature that requires this permission', 'I want to use a specific feature that requires this permission', 'NA', 'NA', 'No', 'NA', 'No', 'NA', 'No', 'NA', 'No', 'NA', 'No', 'NA', '3,3,3,4,4,4,3,3,3', 'No', 'NA', 'NA', 'NA', 'NA', '', '', '', '', '', '', '', '28-01-2018-11-49-12', '28-01-2018-11-55-33', '6.35']
# 5
# 5
# 65
# ['71528', 'PHONE', 'ADIAEAPYRI8CK', 'Android', 'Rarely', 'Agree', 'Female', "Master\\'s or Professional degree (e.g. Law, Medical, Business, etc.)", 'Asian, White', 'more than 18 months', 'Yes', 'Yes', 'I think in the app settings or privacy settings. though some apps will stop working if you do that.', 'No', 'Yes', 'Yes', "I think the app won\\'t work otherwise, I want to use a specific feature that requires this permission, I trust the app developer", 'The app did not ask for that permission/I did not disable the permission/I think thatâ€™s the default setting', '5,5,4', 'No', 'NA', 'NA', 'No', 'NA', 'NA', 'No', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'I want to use a specific feature that requires this permission', 'I want to use a specific feature that requires this permission', "I trust the app developer, Nothing bad will happen, I didn\\'t know I did that", 'NA', 'NA', 'No', 'NA', 'No', 'NA', 'No', 'NA', 'No', 'NA', 'No', 'NA', '1,3,3,3,3,2,3,3,3', 'No', 'NA', 'NA', 'NA', 'NA', '', '', '', '', '', '', '', '28-01-2018-12-36-46', '28-01-2018-12-42-05', '5.3166666666667']
# 5
# 5
# 65
# ['56132', 'LOCATION', 'A34ZP0QJMB8X45', 'Android', 'Rarely', 'Agree', 'Male', 'College graduate (B.S., B.A., or other 4 year degree)', 'Black or African American', '0-6 months', 'Yes', 'Yes', "through the phone\\'s settings", 'No', 'Yes', 'Yes', 'Because the app is popular, I wanted the permission screen to go away, I want to use a specific feature that requires this permission', 'I donâ€™t use the app', '4,4,4,4,4', 'No', 'NA', 'NA', 'No', 'NA', 'NA', 'No', 'NA', 'NA', 'No', 'NA', 'NA', 'No', 'NA', 'NA', "I want to use a specific feature that requires this permission, I think the app won\\'t work otherwise", 'I want to use a specific feature that requires this permission', "I want to use a specific feature that requires this permission, I think the app won\\'t work otherwise", 'I trust the app developer, I want to use a specific feature that requires this permission', 'I want to use a specific feature that requires this permission', 'No', 'NA', 'No', 'NA', 'No', 'NA', 'No', 'NA', 'No', 'NA', '3,3,3,4,3,4,3,3,3', "I don\\'t know", 'I donâ€™t remember', "don\\'t remember", "don\\'t remember", 'Re-enabled the permission', '', '', '', '', '', '', '', '28-01-2018-03-02-34', '28-01-2018-03-10-04', '7.5']
# 5
# 5
# 65
# ['90655', 'PHONE', 'A3EAUAU8V3B5S7', 'Android', 'Rarely', 'Agree', 'Female', 'Some college', 'White', '0-6 months', 'Yes', 'Yes', 'settings, apps, app permissions', 'No', 'Yes', 'NA', 'NA', 'The app did not ask for that permission/I did not disable the permission/I think thatâ€™s the default setting', '5', 'No', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'I trust the app developer, I wanted the permission screen to go away, I have nothing to hide', 'NA', 'NA', 'NA', 'NA', 'No', 'NA', 'No', 'NA', 'No', 'NA', 'No', 'NA', 'No', 'NA', '2,4,4,2,2,4,2,2,2', 'Yes', 'Camera', 'Instagram', "I couldn\\'t browse without granting access", 'Re-enabled the permission', '', '', '', '', '', '', '', '28-01-2018-08-10-14', '28-01-2018-08-13-20', '3.1']
# 5
# 5
# 65
# ['34832', 'MICROPHONE', 'A2QIZ31TMHU0GD', 'Android', 'Rarely', 'Agree', 'Male', 'College graduate (B.S., B.A., or other 4 year degree)', 'Asian', 'more than 18 months', 'Yes', 'No', 'NA', 'NA', 'Yes', 'NA', 'NA', "I don\\'t know", '3,4', 'No', 'NA', 'NA', 'No', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', "I won\\'t be able to grant this permission later", 'Nothing bad will happen', 'NA', 'NA', 'NA', 'No', 'NA', 'No', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', '3,3,4,4,4,4,3,4,4', 'No', 'NA', 'NA', 'NA', 'NA', '', '', '', '', '', '', '', '29-01-2018-11-32-36', '29-01-2018-11-34-55', '2.3166666666667']
# 5
# 5
# 65
# ['30637', 'CONTACTS', 'AT3C00TKZK13L', 'Android', 'Rarely', 'Agree', 'Male', 'College graduate (B.S., B.A., or other 4 year degree)', 'White', '13-18 months', 'Yes', 'Yes', 'going to the app in the settings and changing the access there', 'No', 'Yes', 'NA', 'NA', 'The app did not ask for that permission/I did not disable the permission/I think thatâ€™s the default setting, I expect the app will still work without this permission', '5,5', 'No', 'NA', 'NA', 'No', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'I want to use a specific feature that requires this permission', 'I want to use a specific feature that requires this permission, I trust the app developer', 'NA', 'NA', 'NA', 'No', 'NA', 'No', 'NA', 'No', 'NA', 'NA', 'NA', 'NA', 'NA', '2,4,5,2,4,4,1,2,4', 'No', 'NA', 'NA', 'NA', 'NA', '', '', '', '', '', '', '', '29-01-2018-10-35-23', '29-01-2018-10-39-17', '3.9']
# 5
# 5
# 65
# ...
# 5
# 5
# 65
# ['10389', 'LOCATION', 'AIVSV91CBYI12', 'Android', 'Rarely', 'Agree', 'Female', 'Some college', 'White', 'more than 18 months', 'Yes', 'Yes', "through the Settings app go to applications manager. I think this is how I would do it but I\\'m not certain since I personally have never done it.", 'No', 'Yes', 'No', 'I trust the app developer, I have nothing to hide', "I didn\\'t know I did that", '5,5,5,3,5', 'No', 'NA', 'NA', 'No', 'NA', 'NA', 'No', 'NA', 'NA', 'No', 'NA', 'NA', 'No', 'NA', 'NA', 'I want to use a specific feature that requires this permission', 'I want to use a specific feature that requires this permission', 'I want to use a specific feature that requires this permission', "I don\\'t know", 'I want to use a specific feature that requires this permission', 'No', 'NA', 'No', 'NA', 'No', 'NA', 'No', 'NA', 'No', 'NA', '2,2,2,4,3,3,2,3,3', "I don\\'t know", 'I donâ€™t remember', "I don\\'t recall", "I don\\'t recall", 'Nothing', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', '05-03-2018-02-59-46', '05-03-2018-03-12-05', '12.316666666667']
# 5
# 5
# 65
# ['47726', 'LOCATION', 'A37Q40126A4RNA', 'Android', 'Rarely', 'Agree', 'Male', 'Some college', 'White', 'more than 18 months', 'Yes', 'Yes', 'permissions', 'Yes', 'Yes', 'Yes', 'I want to use a specific feature that requires this permission', 'I donâ€™t use the app', '3,4,4,4,4', 'No', 'NA', 'NA', 'No', 'NA', 'NA', 'No', 'NA', 'NA', 'No', 'NA', 'NA', 'No', 'NA', 'NA', "I didn\\'t know I did that", 'I want to use a specific feature that requires this permission', 'I want to use a specific feature that requires this permission', "I don\\'t know", 'I want to use a specific feature that requires this permission', 'No', 'NA', 'No', 'NA', 'No', 'NA', 'No', 'NA', 'No', 'NA', '1,1,3,3,4,4,3,3,3', 'Yes', 'Contacts', 'flashlight', 'woudnt open', 'Uninstalled the app', 'NA', 'NA', 'NA', 'NA', 'No', 'No', 'strongly agree', '05-03-2018-12-37-12', '05-03-2018-12-43-24', '6.2']
# 5
# 5
# 65
# ['53099', 'CONTACTS', 'A2JLMFZI6MLMFS', 'Android', 'Rarely', 'Agree', 'Male', 'College graduate (B.S., B.A., or other 4 year degree)', 'White', 'more than 18 months', 'Yes', 'Yes', 'go to app permissions in settings', 'Yes', 'Yes', 'Yes', 'I trust the app developer', 'I expect the app will still work without this permission', '5,5,5', 'No', 'NA', 'NA', 'No', 'NA', 'NA', 'No', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'The app developer already has this information about me', 'The app developer already has this information about me, I trust the app developer', 'I trust the app developer', 'NA', 'NA', 'No', 'NA', 'No', 'NA', 'No', 'NA', 'No', 'NA', 'No', 'NA', '3,4,4,3,3,3,3,3,3', 'No', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', '05-03-2018-03-41-53', '05-03-2018-03-45-24', '3.5166666666667']
# 5
# 5
# 65
# ['86824', 'CAMERA', 'A2ASTDMWBCFIP0', 'Android', 'Rarely', 'Agree', 'Female', 'Some college', 'Black or African American', '7-12 months', 'Yes', 'Yes', 'Either when it prompts me when I first open the app to what access it has or go to the settings on my phone or the app itself.', 'Yes', 'Yes', 'Yes', 'I have nothing to hide', "I donâ€™t use the app, I think the app shouldn\\'t need this permission", '4,3,4,4,4', 'No', 'NA', 'NA', 'No', 'NA', 'NA', 'No', 'NA', 'NA', 'Yes', 'No', 'NA', 'Yes', 'No', 'NA', 'I want to use a specific feature that requires this permission', 'I want to use a specific feature that requires this permission', 'I want to use a specific feature that requires this permission', 'I want to use a specific feature that requires this permission', 'I want to use a specific feature that requires this permission', 'No', 'NA', 'No', 'NA', 'No', 'NA', 'No', 'NA', 'No', 'NA', '3,3,4,3,4,3,2,2,3', 'Yes', 'Storage', "I don\\'t remember truthfully", "All I remember is when I denied it, the app just closed out to where I couldn\\'t use it.", 'Re-enabled the permission', 'I permanently enabled the permission for the app and never disabled it again', 'neutral', 'No', 'NA', 'NA', 'NA', 'NA', '05-03-2018-03-44-12', '05-03-2018-03-54-50', '10.633333333333']
# 5
# 5
# 65
# ['73421', 'STORAGE', 'AQAXDL1INQC9Q', 'Android', 'Rarely', 'Agree', 'Female', 'Some college', 'White', '0-6 months', 'Yes', 'Yes', 'Go to the settings and change the settings for each app individually.', 'Yes', 'Yes', 'No', "I think the app won\\'t work otherwise", 'The app did not ask for that permission/I did not disable the permission/I think thatâ€™s the default setting', '4', 'No', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', "I think the app won\\'t work otherwise", 'NA', 'NA', 'NA', 'NA', 'No', 'NA', 'No', 'NA', 'No', 'NA', 'No', 'NA', 'No', 'NA', '3,4,4,3,3,3,2,3,4', 'No', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', '05-03-2018-01-02-00', '05-03-2018-01-07-46', '5.7666666666667']
# 5
# 5
# 65
# ['35245', 'PHONE', 'A2585MULTOM1Z5', 'Android', 'Rarely', 'Agree', 'Female', 'College graduate (B.S., B.A., or other 4 year degree)', 'White', '13-18 months', 'Yes', 'Yes', 'I would protect more personal information better', 'No', 'Yes', 'No', "I think the app won\\'t work otherwise", "I don\\'t know", '2,2,3,3,2', 'No', 'NA', 'NA', 'No', 'NA', 'NA', 'No', 'NA', 'NA', 'No', 'NA', 'NA', 'No', 'NA', 'NA', "I think the app won\\'t work otherwise", "I think the app won\\'t work otherwise", "I think the app won\\'t work otherwise", "I think the app won\\'t work otherwise", "I think the app won\\'t work otherwise", 'No', 'NA', 'No', 'NA', 'No', 'NA', 'No', 'NA', 'No', 'NA', '4,4,5,3,4,2,3,4,4', "I don\\'t know", 'I donâ€™t remember', "I\\'m no sure", 'nothing', 'Nothing', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', '05-03-2018-03-22-34', '05-03-2018-03-27-41', '5.1166666666667']
# 5
# 5
# 65
# ['55661', 'MICROPHONE', 'A1HOSLU4DG2MDS', 'Android', 'Rarely', 'Agree', 'Male', 'Some college', 'White', '0-6 months', 'Yes', 'Yes', 'In the permissions section of the settings menu.', 'Yes', 'No', 'Yes', 'I have nothing to hide, I want to use a specific feature that requires this permission', 'I do not use the specific feature associated with the permission, I can always grant it afterwards if I change my mind', '5,5', 'No', 'NA', 'NA', 'No', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'I trust the app developer, I want to use a specific feature that requires this permission', 'I trust the app developer, I want to use a specific feature that requires this permission', 'NA', 'NA', 'NA', 'No', 'NA', 'No', 'NA', 'No', 'NA', 'No', 'NA', 'No', 'NA', '2,2,2,4,2,2,3,3,4', 'Yes', 'Contacts', 'Instagram', 'did not want my contacts to be added to my account', 'Nothing', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', '05-03-2018-04-36-14', '05-03-2018-04-41-48', '5.5666666666667']
# 5
# 5
# 65
# ['20375', 'MICROPHONE', 'A1160COTUR26JZ', 'Android', 'Rarely', 'Agree', 'Female', 'Some college', 'White', 'more than 18 months', 'Yes', 'Yes', 'by going to settings>apps>application manager> then choosing the app I wanted to make changes to.', 'Yes', 'Yes', 'Yes', "I wanted the permission screen to go away, I think the app won\\'t work otherwise", "I think the app shouldn\\'t need this permission, I wanted the permission screen to go away", '2', 'No', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', "I don\\'t know, I wanted the permission screen to go away", 'NA', 'NA', 'NA', 'NA', 'No', 'NA', 'No', 'NA', 'No', 'NA', 'No', 'NA', 'No', 'NA', '5,5,5,5,5,5,5,5,5', 'Yes', 'Contacts', "I don\\'t remember", 'It would close out the app', 'Re-enabled the permission', 'I permanently enabled the permission for the app and never disabled it again', 'neutral', 'No', 'NA', 'NA', 'NA', 'NA', '05-03-2018-03-36-58', '05-03-2018-03-43-13', '6.25']
# 5
# 5
# 65
# ['10680', 'MICROPHONE', 'A302M81U0HM7RJ', 'Android', 'Rarely', 'Agree', 'Male', 'Some college', 'White', '13-18 months', 'Yes', 'Yes', 'Go to settings, then apps, then usage', 'No', 'Yes', 'No', "I didn\\'t know I did that", 'I can always grant it afterwards if I change my mind', '5,4,3,5', 'No', 'NA', 'NA', 'No', 'NA', 'NA', 'Yes', 'No', 'NA', 'No', 'NA', 'NA', 'NA', 'NA', 'NA', "I think the app won\\'t work otherwise", "I don\\'t know", "I didn\\'t know I did that", "I trust the app developer, Because the app is popular, I think the app won\\'t work otherwise, I have nothing to hide, The app developer already has this information about me, Nothing bad will happen", 'NA', 'No', 'NA', 'No', 'NA', 'No', 'NA', 'No', 'NA', 'No', 'NA', '3,4,4,3,5,5,4,3,5', 'Yes', 'Storage', "Don\\'t remember exact name but it was an mom game that said it required it to save.", "It wouldn\\'t save without that access allowed", 'Uninstalled the app', 'NA', 'NA', 'NA', 'NA', 'No', 'No', 'strongly agree', '05-03-2018-04-40-28', '05-03-2018-04-45-27', '4.9833333333333']
# 5
# 5
# 65
# ['91746', 'CONTACTS', 'AIEJ3ECA0KG9F', 'Android', 'Rarely', 'Agree', 'Female', 'Some college', 'Black or African American', 'more than 18 months', 'Yes', 'Yes', 'go to settings and go to apps and chose the app you would like to change.', 'Yes', 'Yes', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', '3,3,4,5,2,5,4,5,5', 'No', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', '05-03-2018-03-45-59', '05-03-2018-03-48-34', '2.5833333333333']
# 5
# 5
# 65
# ['76987', 'CAMERA', 'A1KF05U5IO9AFG', 'Android', 'Rarely', 'Agree', 'Female', 'Some college', 'Black or African American, White', '13-18 months', 'Yes', 'Yes', 'I would change the permission of the specific app.', 'Yes', 'Yes', 'Yes', "I wanted the permission screen to go away, Because the app is popular, I trust the app developer, I think the app won\\'t work otherwise", 'I expect the app will still work without this permission, I can always grant it afterwards if I change my mind', '5,5', 'No', 'NA', 'NA', 'No', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'I have nothing to hide, I want to use a specific feature that requires this permission', 'I want to use a specific feature that requires this permission', 'NA', 'NA', 'NA', 'Yes', "I expect the app will still work without this permission, I think the app shouldn\\'t need this permission", 'Yes', 'I expect the app will still work without this permission', 'No', 'NA', 'No', 'NA', 'No', 'NA', '2,4,2,4,1,1,1,4,4', 'Yes', 'Camera', 'Snapchat', "I couldn\\'t take pictures without allowing the permission.", 'Re-enabled the permission', 'I permanently enabled the permission for the app and never disabled it again', 'strongly agree', 'No', 'NA', 'NA', 'NA', 'NA', '05-03-2018-05-15-40', '05-03-2018-05-23-58', '8.3']
# 5
# 5
# 65
# ['38587', 'CAMERA', 'AOX8BJNGGNDZH', 'Android', 'Rarely', 'Agree', 'Other: Transmasculine', 'Some college', 'White', '13-18 months', 'Yes', 'Yes', 'By unchecking boxes during installation.', 'Yes', 'Yes', 'Yes', 'I trust the app developer, I want to use a specific feature that requires this permission', "I expect the app will still work without this permission, I do not use the specific feature associated with the permission, I think the app shouldn\\'t need this permission", '4,2,4,4,4', 'No', 'NA', 'NA', 'No', 'NA', 'NA', 'No', 'NA', 'NA', 'No', 'NA', 'NA', 'No', 'NA', 'NA', 'I want to use a specific feature that requires this permission', "I didn\\'t know I did that", 'I want to use a specific feature that requires this permission', 'I want to use a specific feature that requires this permission', 'I want to use a specific feature that requires this permission', 'No', 'NA', 'No', 'NA', 'No', 'NA', 'Yes', "I don\\'t trust the developer enough to provide this information, I think the app shouldn\\'t need this permission", 'No', 'NA', '4,4,4,4,4,4,4,4,4', 'Yes', 'Location', 'Google Maps', 'App crashed due to turning off location permissions', 'Re-enabled the permission', 'I temporarily enabled the permission for the app (for a specific time) then disabeld it later', 'neutral', 'No', 'NA', 'NA', 'NA', 'NA', '05-03-2018-03-19-57', '05-03-2018-03-27-58', '8.0166666666667']
# 5
# 5
# 65
# ['39153', 'PHONE', 'A276N5FFOSK2FX', 'Android', 'Rarely', 'Agree', 'Male', 'Some college', 'White', '0-6 months', 'Yes', 'Yes', 'Through settings and then apps then app permissions', 'Yes', 'Yes', 'Yes', 'I want to use a specific feature that requires this permission', 'I do not use the specific feature associated with the permission', '5,5,5,5', 'No', 'NA', 'NA', 'No', 'NA', 'NA', 'No', 'NA', 'NA', 'No', 'NA', 'NA', 'NA', 'NA', 'NA', "I didn\\'t know I did that", 'I want to use a specific feature that requires this permission', 'I want to use a specific feature that requires this permission', 'I want to use a specific feature that requires this permission', 'NA', 'No', 'NA', 'No', 'NA', 'No', 'NA', 'No', 'NA', 'No', 'NA', '3,2,2,2,2,2,2,2,2', 'No', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', '05-03-2018-06-19-30', '05-03-2018-06-27-50', '8.3333333333333']
# 5
# 5
# 65
# ['41877', 'STORAGE', 'A17F6MB9SZYV57', 'Android', 'Rarely', 'Agree', 'Male', 'Some college', 'Asian', 'more than 18 months', 'Yes', 'Yes', 'Settings>Privacy>App Permissions', 'No', 'Yes', 'Yes', 'I trust the app developer, Because the app is popular', 'The app did not ask for that permission/I did not disable the permission/I think thatâ€™s the default setting', '5,4,4,4,4', 'No', 'NA', 'NA', 'No', 'NA', 'NA', 'No', 'NA', 'NA', 'Yes', 'No', 'NA', 'No', 'NA', 'NA', "I trust the app developer, I think the app won\\'t work otherwise", 'I want to use a specific feature that requires this permission', 'I trust the app developer', "I think the app won\\'t work otherwise", "I think the app won\\'t work otherwise", 'No', 'NA', 'No', 'NA', 'No', 'NA', 'No', 'NA', 'No', 'NA', '3,5,4,5,4,3,2,4,4', 'Yes', 'Location', 'Maps', 'Did not work', 'Re-enabled the permission', 'I temporarily enabled the permission for the app (for a specific time) then disabeld it later', 'agree', 'No', 'NA', 'NA', 'NA', 'NA', '05-03-2018-03-54-05', '05-03-2018-03-59-47', '5.7']
# 5
# 5
# 65
# ['40634', 'CONTACTS', 'A184EIWAV7P9EH', 'Android', 'Rarely', 'Agree', 'Male', 'Some college', 'Asian', '7-12 months', 'Yes', 'Yes', 'Go to Settings>Applications>Application Manager>Click app name>Permissions', 'No', 'Yes', 'Yes', 'I want to use a specific feature that requires this permission', 'I do not use the specific feature associated with the permission', '5,3,5,5,5', 'No', 'NA', 'NA', 'No', 'NA', 'NA', 'No', 'NA', 'NA', 'No', 'NA', 'NA', 'Yes', 'No', 'NA', 'I have nothing to hide, I trust the app developer, The app developer already has this information about me', 'I have nothing to hide', 'I trust the app developer, I have nothing to hide', 'I trust the app developer', 'I trust the app developer', 'No', 'NA', 'No', 'NA', 'No', 'NA', 'No', 'NA', 'No', 'NA', '3,4,5,3,5,5,3,5,5', "I don\\'t know", 'I donâ€™t remember', 'Not Applicable', 'Not Applicable', 'Other: Not Applicable', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', '06-03-2018-03-41-55', '06-03-2018-03-51-22', '9.45']
# 5
# 5
# 65
# ['37690', 'PHONE', 'A2UOBJK4K2SB4U', 'Android', 'Rarely', 'Agree', 'Female', 'Some college', 'White', 'more than 18 months', 'Yes', 'No', 'NA', 'NA', 'Yes', 'No', "I think the app won\\'t work otherwise", 'The app did not ask for that permission/I did not disable the permission/I think thatâ€™s the default setting', '5,5,5', 'No', 'NA', 'NA', 'No', 'NA', 'NA', 'No', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', "I didn\\'t know I did that", "I didn\\'t know I did that", "I didn\\'t know I did that", 'NA', 'NA', 'No', 'NA', 'No', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', '5,5,5,5,5,5,5,5,5', 'No', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', '06-03-2018-02-12-55', '06-03-2018-02-17-13', '4.3']

# %%
#prepare permissions table
#Get the data for the permission table (combine requested and granted in one):
#insert into permissions(TurkerID,randomint,appName, appType,targetSDK,requestedPerms,grantedPerms)
#select a.`TurkerID`, a.`randomint`, a.`appName`,a.`appType`, a.`targetSDK`, a.`perms`, b.`perms` from requestedPerms a, grantedPerms b where a.`id`=b.`id`
permissionsQ = ("insert into permissions(TurkerID,randomint,appName, appType,targetSDK,requestedPerms,grantedPerms) select a.`TurkerID`, a.`randomint`, a.`appName`,a.`appType`, a.`targetSDK`, a.`perms`, b.`perms` from requestedPerms a, grantedPerms b where a.`id`=b.`id`")
cursor2=cnx.cursor()
number_of_rows2=cursor2.execute(permissionsQ)
cnx.commit()

# %%
number_of_rows2
# Out:
# 24745

# %%
#prepare danger data
cursor = cnx.cursor()

query = ("select a.*, b.danger from permissions a, survey2 b where a.`TurkerID`=b.`TurkerID`")

cursor.execute(query)


#for (x) in cursor:
  #print("{}".format(x))

requestedPerm = {'MICROPHONE':0,'LOCATION':0,'CAMERA':0,'CONTACTS':0,'PHONE':0,'STORAGE':0,'CALENDAR':0,'SENSORS':0,'SMS':0}
grantedPerm = {'MICROPHONE':0,'LOCATION':0,'CAMERA':0,'CONTACTS':0,'PHONE':0,'STORAGE':0,'CALENDAR':0,'SENSORS':0,'SMS':0}

with open('dangerLevel_out.csv','w') as out:
    #myFields = ['TurkerID', 'number of permissions requested for microphone', 'number of permissions requested for location', 'number of permissions requested for camera', 'number of permissions requested for contacts', 'number of permissions requested for phone', 'number of permissions requested for storage', 'number of permissions requested for calendar','number of permissions requested sensor','number of permissions requested sms','number of permissions granted for microphone', 'number of permissions granted for location', 'number of permissions granted for camera', 'number of permissions granted for contacts', 'number of permissions granted for phone', 'number of permissions granted for storage', 'number of permissions granted for calendar','number of permissions granted sensor','number of permissions granted sms','danger level of microphone','danger level of location','danger level of camera','danger level of contacts','danger level of phone','danger level of storage','danger level of calendar','danger level of sensor','danger level of sms']
    myFields = ['TurkerID', 'number of apps requested microphone', 'number of apps requested location', 'number of apps requested camera', 'number of apps requested contacts', 'number of apps requested phone', 'number of apps requested storage', 'number of apps requested calendar','number of apps requested sensor','number of apps requested sms','number of apps granted microphone', 'number of apps granted location', 'number of apps granted camera', 'number of apps granted contacts', 'number of apps granted phone', 'number of apps granted storage', 'number of apps granted calendar','number of apps granted sensor','number of apps granted sms','danger level of microphone','danger level of location','danger level of camera','danger level of contacts','danger level of phone','danger level of storage','danger level of calendar','danger level of sensor','danger level of sms']
    writer = csv.DictWriter(out, fieldnames=myFields)
    writer.writeheader()
    prevTurk = 'nonsense'
    check = -1
    for row in cursor:
        if row[1] != prevTurk:
                if check != -1:
                    
                    #writer.writerow({'TurkerID':prevTurk,'number of permissions requested for microphone':requestedPerm['MICROPHONE'], 'number of permissions requested for location':requestedPerm['LOCATION'], 'number of permissions requested for camera':requestedPerm['CAMERA'], 'number of permissions requested for contacts':requestedPerm['CONTACTS'], 'number of permissions requested for phone':requestedPerm['PHONE'], 'number of permissions requested for storage':requestedPerm['STORAGE'], 'number of permissions requested for calendar':requestedPerm['CALENDAR'],'number of permissions requested sensor':requestedPerm['SENSORS'],'number of permissions requested sms':requestedPerm['SMS'],'number of permissions granted for microphone':grantedPerm['MICROPHONE'], 'number of permissions granted for location':grantedPerm['LOCATION'], 'number of permissions granted for camera':grantedPerm['CAMERA'], 'number of permissions granted for contacts':grantedPerm['CONTACTS'], 'number of permissions granted for phone':grantedPerm['PHONE'], 'number of permissions granted for storage':grantedPerm['STORAGE'], 'number of permissions granted for calendar':grantedPerm['CALENDAR'],'number of permissions granted sensor':grantedPerm['SENSORS'],'number of permissions granted sms':grantedPerm['SMS'],'danger level of microphone':danger[0],'danger level of location':danger[1],'danger level of camera':danger[2],'danger level of contacts':danger[3],'danger level of phone':danger[4],'danger level of storage':danger[5],'danger level of calendar':danger[6],'danger level of sensor':danger[7],'danger level of sms':danger[8]})
                    writer.writerow({'TurkerID':prevTurk,'number of apps requested microphone':requestedPerm['MICROPHONE'], 'number of apps requested location':requestedPerm['LOCATION'], 'number of apps requested camera':requestedPerm['CAMERA'], 'number of apps requested contacts':requestedPerm['CONTACTS'], 'number of apps requested phone':requestedPerm['PHONE'], 'number of apps requested storage':requestedPerm['STORAGE'], 'number of apps requested calendar':requestedPerm['CALENDAR'],'number of apps requested sensor':requestedPerm['SENSORS'],'number of apps requested sms':requestedPerm['SMS'],'number of apps granted microphone':grantedPerm['MICROPHONE'], 'number of apps granted location':grantedPerm['LOCATION'], 'number of apps granted camera':grantedPerm['CAMERA'], 'number of apps granted contacts':grantedPerm['CONTACTS'], 'number of apps granted phone':grantedPerm['PHONE'], 'number of apps granted storage':grantedPerm['STORAGE'], 'number of apps granted calendar':grantedPerm['CALENDAR'],'number of apps granted sensor':grantedPerm['SENSORS'],'number of apps granted sms':grantedPerm['SMS'],'danger level of microphone':danger[0],'danger level of location':danger[1],'danger level of camera':danger[2],'danger level of contacts':danger[3],'danger level of phone':danger[4],'danger level of storage':danger[5],'danger level of calendar':danger[6],'danger level of sensor':danger[7],'danger level of sms':danger[8]})
                    prevTurk = row[1]
                    #re-initialize
                    requestedPerm = {'MICROPHONE':0,'LOCATION':0,'CAMERA':0,'CONTACTS':0,'PHONE':0,'STORAGE':0,'CALENDAR':0,'SENSORS':0,'SMS':0}
                    grantedPerm = {'MICROPHONE':0,'LOCATION':0,'CAMERA':0,'CONTACTS':0,'PHONE':0,'STORAGE':0,'CALENDAR':0,'SENSORS':0,'SMS':0}
                
                else:
                    check = 1
                    prevTurk = row[1]
    
    
        
        rPerm = row[6].strip('[]')
        gPerm = row[7].strip('[]')
            
        rrPerm = rPerm.split(',')
        ggPerm = gPerm.split(',')
            
        for x in rrPerm:
            x = x.strip()
            if x != '':
                requestedPerm[x] = requestedPerm[x] + 1
        for y in ggPerm:
            y = y.strip()
            if y != '':
                grantedPerm[y] = grantedPerm[y] + 1
        
        danger = row[8].split(',')
        


dfDanger = pandas.read_csv('dangerLevel_out.csv',sep=',')
        
#cursor.close()
#cnx.close()

# %%
dfDanger.head()
# Out:
#           TurkerID  number of apps requested microphone  \
# 0    A4IH4CO046EV3                                   30
# 5   A1HUWK2J3GF1OY                                   30
# 10  A1MURUJBBDJWM6                                   74
# 16  A1DS5O8MSI3ZH0                                   78
# 17   APY5858P6BTDY                                   40
#
#     number of apps requested location  number of apps requested camera  \
# 0                                  60                               42
# 5                                  26                               32
# 10                                124                               88
# 16                                182                              118
# 17                                 60                               56
#
#     number of apps requested contacts  number of apps requested phone  \
# 0                                  54                              52
# 5                                  40                              24
# 10                                124                             118
# 16                                144                             132
# 17                                 88                              96
#
#     number of apps requested storage  number of apps requested calendar  \
# 0                                 78                                  6
# 5                                 50                                  2
# 10                               162                                 30
# 16                               214                                 28
# 17                               126                                 18
#
#     number of apps requested sensor  number of apps requested sms  \
# 0                                 2                            18
# 5                                 2                            16
# 10                                2                            64
# 16                                4                            66
# 17                                2                            54
#
#            ...           number of apps granted sms  \
# 0          ...                                    0
# 5          ...                                    6
# 10         ...                                   48
# 16         ...                                   38
# 17         ...                                   30
#
#     danger level of microphone  danger level of location  \
# 0                            2                         2
# 5                            2                         3
# 10                           3                         3
# 16                           2                         3
# 17                           3                         4
#
#     danger level of camera  danger level of contacts  danger level of phone  \
# 0                        4                         4                      4
# 5                        4                         3                      4
# 10                       2                         3                      3
# 16                       2                         4                      4
# 17                       4                         3                      4
#
#     danger level of storage  danger level of calendar  danger level of sensor  \
# 0                         4                         1                       1
# 5                         2                         2                       3
# 10                        3                         2                       3
# 16                        4                         3                       4
# 17                        3                         4                       4
#
#     danger level of sms
# 0                     4
# 5                     2
# 10                    3
# 16                    4
# 17                    4
#
# [5 rows x 28 columns]

# %%
#prepare usage time data

query = ("select a.* , b.`usagetime` from permissions a , usageTime b where a.`TurkerID`=b.`TurkerID` and a.`appName`=b.`appName` order by b.TurkerID, b.usageTime")

cursor.execute(query)

with open('out.csv','w') as out:
    myFields = ['TurkerID', 'randomint', 'appName', 'appType', 'targetSDK', 'requestedPerms', 'grantedPerms', 'usagetime','number of permissions requested','number of permissions granted']
    writer = csv.DictWriter(out, fieldnames=myFields)
    writer.writeheader()
    for row in cursor:
        rPerm = row[6].strip('[]')
        gPerm = row[7].strip('[]')
        writer.writerow({'TurkerID':row[1], 'randomint':row[2], 'appName':row[3], 'appType':row[4], 'targetSDK':row[5], 'requestedPerms':row[6], 'grantedPerms':row[7], 'usagetime':row[8],'number of permissions requested':len(rPerm.split()),'number of permissions granted':len(gPerm.split())})



        
        
dfUsage = pandas.read_csv('out.csv',sep=',')
        
cursor.close()
#cnx.close()

# %%
dfUsage.head()
# Out:
#                TurkerID  randomint            appName appType  targetSDK  \
# 0  A002160837SWJFPIAI7L      87492           My Files  system         24
# 1  A002160837SWJFPIAI7L      87492           My Files  system         24
# 2  A002160837SWJFPIAI7L      87492        Apps Survey    user         23
# 3  A002160837SWJFPIAI7L      87492        Apps Survey    user         23
# 4  A002160837SWJFPIAI7L      87492  Google Play Music  system         26
#
#                   requestedPerms grantedPerms  usagetime  \
# 0                      [STORAGE]    [STORAGE]          1
# 1                      [STORAGE]    [STORAGE]          1
# 2                             []           []          2
# 3                             []           []          2
# 4  [LOCATION, STORAGE, CONTACTS]    [STORAGE]          3
#
#    number of permissions requested  number of permissions granted
# 0                                1                              1
# 1                                1                              1
# 2                                0                              0
# 3                                0                              0
# 4                                3                              1

# %%
#close DB connection
cnx.close()

# %%
#stat analysis
from scipy import stats
from pydoc import help
from scipy.stats.stats import pearsonr
from scipy.stats.stats import spearmanr
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.pyplot as plt
import numpy as np
#help(pearsonr)


#calculate the correlation between the perception of danger and number of times the permission was granted
#data = pandas.read_csv('/Users/QN/Desktop/THIRD crowdperm/Analysis code/dangerLevel_out.csv', sep=',', na_values=".")
#data=dfDanger
#location
x=dfDanger['danger level of location']
y=dfDanger['number of apps granted location']/dfDanger['number of apps requested location']
#spearmanr(x,y)
location=pearsonr(x, y)

plt.scatter(x,y,marker='.')
plt.xlabel('perception of danger for location')
plt.ylabel('% of granted permissions')
plt.show()


#mic
x=dfDanger['danger level of microphone']
y=dfDanger['number of apps granted microphone']/dfDanger['number of apps requested microphone']
mic=pearsonr(x, y)

plt.scatter(x,y,marker='.')
plt.xlabel('perception of danger for microphone')
plt.ylabel('% of granted permissions')
plt.show()

#camera
x=dfDanger['danger level of camera']
y=dfDanger['number of apps granted camera']/dfDanger['number of apps requested camera']
camera=pearsonr(x, y)

plt.scatter(x,y,marker='.')
plt.xlabel('perception of danger for camera')
plt.ylabel('% of granted permissions')
plt.show()

#contacts
x=dfDanger['danger level of contacts']
y=dfDanger['number of apps granted contacts']/dfDanger['number of apps requested contacts']
contacts =pearsonr(x, y)

plt.scatter(x,y,marker='.')
plt.xlabel('perception of danger for contacts')
plt.ylabel('% of granted permissions')
plt.show()


#phone
x=dfDanger['danger level of phone']
y=dfDanger['number of apps granted phone']/dfDanger['number of apps requested phone']
phone =pearsonr(x, y)

plt.scatter(x,y,marker='.')
plt.xlabel('perception of danger for phone')
plt.ylabel('% of granted permissions')
plt.show()

#storage
x=dfDanger['danger level of storage']
y=dfDanger['number of apps granted storage']/dfDanger['number of apps requested storage']
storage =pearsonr(x, y)

plt.scatter(x,y,marker='.')
plt.xlabel('perception of danger for storage')
plt.ylabel('% of granted permissions')
plt.show()

#skip the rows with zero requested permissions
dfDanger=dfDanger[dfDanger['number of apps requested sensor'] > 0]
dfDanger=dfDanger[dfDanger['number of apps requested sms'] > 0]

#sms
x=dfDanger['danger level of sms']
y=dfDanger['number of apps granted sms']/dfDanger['number of apps requested sms']
sms =pearsonr(x, y)

plt.scatter(x,y,marker='.')
plt.xlabel('perception of danger for sms')
plt.ylabel('% of granted permissions')
plt.show()

#calendar
x=dfDanger['danger level of calendar']
y=dfDanger['number of apps granted calendar']/dfDanger['number of apps requested calendar']
calendar =pearsonr(x, y)

plt.scatter(x,y,marker='.')
plt.xlabel('perception of danger for calendar')
plt.ylabel('% of granted permissions')
plt.show()

#sensor
x=dfDanger['danger level of sensor']
y=dfDanger['number of apps granted sensor']/dfDanger['number of apps requested sensor']
sensor =pearsonr(x, y)

plt.scatter(x,y,marker='.')
plt.xlabel('perception of danger for sensor')
plt.ylabel('% of granted permissions')
plt.show()


print("Location correlation: ")
print(location)

print("Camera correlation: ")
print(camera)

print("Microphone correlation: ")
print(mic)

print("Phone correlation: ")
print(phone)

print("Contacts correlation: ")
print(contacts)

print("Storage correlation: ")
print(storage)

print("sms correlation: ")
print(sms)

print("sensor correlation: ")
print(sensor)

print("calendar correlation: ")
print(calendar)
#plt.plot(x,y)
#plt.show()
# Out:
# Location correlation:
# (0.020983127295163377, 0.57779467756379743)
# Camera correlation:
# (-0.047812333511629786, 0.20448390675918018)
# Microphone correlation:
# (0.083111612849118416, 0.02722762644038676)
# Phone correlation:
# (0.03171196455807046, 0.4001651244297787)
# Contacts correlation:
# (0.020010154500775049, 0.59556151413904213)
# Storage correlation:
# (0.02656030383159327, 0.48106007667788409)
# sms correlation:
# (0.1710637201240679, 0.00068176986171699543)
# sensor correlation:
# (0.063632057016842727, 0.2093021389151532)
# calendar correlation:
# (0.15706706695956363, 0.001838115608193805)

# %%
#plot the perception of permission danger 
permissionsMeans=[dfDanger['danger level of location'].mean(),dfDanger['danger level of camera'].mean(),dfDanger['danger level of contacts'].mean(),dfDanger['danger level of microphone'].mean(),dfDanger['danger level of calendar'].mean(),dfDanger['danger level of storage'].mean(),dfDanger['danger level of phone'].mean(),dfDanger['danger level of sms'].mean(),dfDanger['danger level of sensor'].mean()]
print(permissionsMeans)
#plt.scatter(permissionNames,permissionsMeans)
plt.plot(permissionsMeans,'o')
plt.xticks([0, 1, 2,3,4,5,6,7,8],['location','camera','contacts','microphone','calendar','storage','phone','sms','sensors'])
plt.xticks(rotation=45)
plt.xlabel('permission name')
plt.ylabel('mean of the danger level perception (for all participants)')
plt.show()
# Out:
# [3.575447570332481, 3.506393861892583, 3.5191815856777495, 3.1432225063938617, 2.7161125319693094, 3.3273657289002556, 3.475703324808184, 3.4296675191815855, 2.9335038363171355]

# %%
#test the hypothesis "Most frequently used apps are less restricted"
#In other words: the higher the usage time, the higher the number of granted permissions"
#read usage time file into a dataframe
usagedata=dfUsage

#try again with another filter
#skip the rows with zero requested permissions
usagedata=usagedata[usagedata['number of permissions requested'] > 4]
x=usagedata['usagetime']
y=usagedata['number of permissions granted']/usagedata['number of permissions requested']
#spearmanr(x,y)
pearsonr(x, y)


#plot the usagetime vs. %of granted permissions
import matplotlib.pyplot as plt
import numpy as np
#x=np.log(x)
plt.scatter(x/60,y,marker='.')
plt.xlabel('usage time')
plt.ylabel('% of granted permissions')
#plt.xscale('log')
#plt.plot(x,y)
#plt.plot(y)
plt.show()

# %%
pearsonr(x, y)
# Out:
# (0.049753789286150985, 1.3624716247152778e-07)

# %%
plt.xscale('log')
plt.scatter(x,y,marker='.')
plt.xlabel('usage time')
plt.ylabel('% of granted permissions')
plt.show()

# %%
location=dfDanger['number of apps granted location']/dfDanger['number of apps requested location']
camera=dfDanger['number of apps granted camera']/dfDanger['number of apps requested camera']
contacts=dfDanger['number of apps granted contacts']/dfDanger['number of apps requested contacts']
microphone=dfDanger['number of apps granted microphone']/dfDanger['number of apps requested microphone']
calendar=dfDanger['number of apps granted calendar']/dfDanger['number of apps requested calendar']
storage=dfDanger['number of apps granted storage']/dfDanger['number of apps requested storage']
phone=dfDanger['number of apps granted phone']/dfDanger['number of apps requested phone']
sms=dfDanger['number of apps granted sms']/dfDanger['number of apps requested sms']
sensors=dfDanger['number of apps granted sensor']/dfDanger['number of apps requested sensor']

permissionCounts=[location,camera,contacts,microphone,calendar,storage,phone,sms,sensors]
permissionsMeans=[location.mean(),camera.mean(),contacts.mean(),microphone.mean(),calendar.mean(),storage.mean(),phone.mean(),sms.mean(),sensors.mean()]
permissionNames=['location','camera','contacts','microphone','calendar','storage','phone','sms','sensors']

plt.figure()
plt.boxplot(permissionCounts)
plt.xticks([1, 2, 3,4,5,6,7,8,9],['location','camera','contacts','microphone','calendar','storage','phone','sms','sensors'])
plt.xticks(rotation=45)
plt.xlabel('permission name')
plt.ylabel('fraction of times it was granted')
plt.show()


#plt.scatter(permissionNames,permissionsMeans)
plt.plot(permissionsMeans,'o')
plt.xticks([0, 1, 2,3,4,5,6,7,8],['location','camera','contacts','microphone','calendar','storage','phone','sms','sensors'])
plt.xticks(rotation=45)
plt.xlabel('permission name')
plt.ylabel('mean of the number of times it was granted (for all participants)')
plt.show()

# %%
#look at the story questions
#select * from survey2 where story !='No'
#in stories:
#compare the comfort level for re-enabling the permission vs. deleting the app 
from scipy.stats.stats import mannwhitneyu
from scipy.stats.stats import ttest_ind

#read the survey2 table into a dataframe
surveyData=pandas.read_sql_query("select * from survey2", cnx) 
#focus only on stories
stories=surveyData[surveyData['storySolve']!='NA']

#coding the comfort level questions 
storyUninstallComfort=[]
storyEnableComfort=[]
for index, row in stories.iterrows():
    #print (row['storyUninstallComfort'], row['storyEnableComfort'])
    if row['storyUninstallComfort'] == 'strongly agree':
        storyUninstallComfort.append(5)
    if row['storyUninstallComfort'] == 'agree':
        storyUninstallComfort.append(4)
    if row['storyUninstallComfort'] == 'neutral':
        storyUninstallComfort.append(3)
    if row['storyUninstallComfort'] == 'disagree':
        storyUninstallComfort.append(2)
    if row['storyUninstallComfort'] == 'strongly disagree':
        storyUninstallComfort.append(1)
        
    if row['storyEnableComfort'] == 'strongly agree':
        storyEnableComfort.append(5)
    if row['storyEnableComfort'] == 'agree':
        storyEnableComfort.append(4)
    if row['storyEnableComfort'] == 'neutral':
        storyEnableComfort.append(3)
    if row['storyEnableComfort'] == 'disagree':
        storyEnableComfort.append(2)
    if row['storyEnableComfort'] == 'strongly disagree':
        storyEnableComfort.append(1)

        
x=storyEnableComfort
y=storyUninstallComfort
#mannwhitneyu(x, y, use_continuity=True, alternative=None)
ttest_ind(x, y, axis=0, equal_var=True)
# Out:
# ---------------------------------------------------------------------------
# InterfaceError                            Traceback (most recent call last)
# /anaconda3/lib/python3.6/site-packages/pandas/io/sql.py in execute(self, *args, **kwargs)
#    1403             else:
# -> 1404                 cur.execute(*args)
#    1405             return cur
#
# /anaconda3/lib/python3.6/site-packages/pymysql/cursors.py in execute(self, query, args)
#     164
# --> 165         result = self._query(query)
#     166         self._executed = query
#
# /anaconda3/lib/python3.6/site-packages/pymysql/cursors.py in _query(self, q)
#     320         self._last_executed = q
# --> 321         conn.query(q)
#     322         self._do_get_result()
#
# /anaconda3/lib/python3.6/site-packages/pymysql/connections.py in query(self, sql, unbuffered)
#     858                 sql = sql.encode(self.encoding, 'surrogateescape')
# --> 859         self._execute_command(COMMAND.COM_QUERY, sql)
#     860         self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#
# /anaconda3/lib/python3.6/site-packages/pymysql/connections.py in _execute_command(self, command, sql)
#    1074         if not self._sock:
# -> 1075             raise err.InterfaceError("(0, '')")
#    1076
#
# InterfaceError: (0, '')
#
# During handling of the above exception, another exception occurred:
#
# InterfaceError                            Traceback (most recent call last)
# /anaconda3/lib/python3.6/site-packages/pandas/io/sql.py in execute(self, *args, **kwargs)
#    1407             try:
# -> 1408                 self.con.rollback()
#    1409             except Exception:  # pragma: no cover
#
# /anaconda3/lib/python3.6/site-packages/pymysql/connections.py in rollback(self)
#     784         """Roll back the current transaction"""
# --> 785         self._execute_command(COMMAND.COM_QUERY, "ROLLBACK")
#     786         self._read_ok_packet()
#
# /anaconda3/lib/python3.6/site-packages/pymysql/connections.py in _execute_command(self, command, sql)
#    1074         if not self._sock:
# -> 1075             raise err.InterfaceError("(0, '')")
#    1076
#
# InterfaceError: (0, '')
#
# During handling of the above exception, another exception occurred:
#
# DatabaseError                             Traceback (most recent call last)
# <ipython-input-16-d7921fa1c843> in <module>()
#       7
#       8 #read the survey2 table into a dataframe
# ----> 9 surveyData=pandas.read_sql_query("select * from survey2", cnx)
#      10 #focus only on stories
#      11 stories=surveyData[surveyData['storySolve']!='NA']
#
# /anaconda3/lib/python3.6/site-packages/pandas/io/sql.py in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize)
#     330     return pandas_sql.read_query(
#     331         sql, index_col=index_col, params=params, coerce_float=coerce_float,
# --> 332         parse_dates=parse_dates, chunksize=chunksize)
#     333
#     334
#
# /anaconda3/lib/python3.6/site-packages/pandas/io/sql.py in read_query(self, sql, index_col, coerce_float, params, parse_dates, chunksize)
#    1437
#    1438         args = _convert_params(sql, params)
# -> 1439         cursor = self.execute(*args)
#    1440         columns = [col_desc[0] for col_desc in cursor.description]
#    1441
#
# /anaconda3/lib/python3.6/site-packages/pandas/io/sql.py in execute(self, *args, **kwargs)
#    1410                 ex = DatabaseError("Execution failed on sql: %s\n%s\nunable"
#    1411                                    " to rollback" % (args[0], exc))
# -> 1412                 raise_with_traceback(ex)
#    1413
#    1414             ex = DatabaseError(
#
# /anaconda3/lib/python3.6/site-packages/pandas/compat/__init__.py in raise_with_traceback(exc, traceback)
#     342         if traceback == Ellipsis:
#     343             _, _, traceback = sys.exc_info()
# --> 344         raise exc.with_traceback(traceback)
#     345 else:
#     346     # this version of raise is a syntax error in Python 3
#
# /anaconda3/lib/python3.6/site-packages/pandas/io/sql.py in execute(self, *args, **kwargs)
#    1406         except Exception as exc:
#    1407             try:
# -> 1408                 self.con.rollback()
#    1409             except Exception:  # pragma: no cover
#    1410                 ex = DatabaseError("Execution failed on sql: %s\n%s\nunable"
#
# /anaconda3/lib/python3.6/site-packages/pymysql/connections.py in rollback(self)
#     783     def rollback(self):
#     784         """Roll back the current transaction"""
# --> 785         self._execute_command(COMMAND.COM_QUERY, "ROLLBACK")
#     786         self._read_ok_packet()
#     787
#
# /anaconda3/lib/python3.6/site-packages/pymysql/connections.py in _execute_command(self, command, sql)
#    1073     def _execute_command(self, command, sql):
#    1074         if not self._sock:
# -> 1075             raise err.InterfaceError("(0, '')")
#    1076
#    1077         # If the last query was unbuffered, make sure it finishes before
#
# DatabaseError: Execution failed on sql: select * from survey2
# (0, '')
# unable to rollback

# %%
lines
# Out:
# ['qismail', 'i love Looly al7lo']

# %%
 u=",".join([str(x) for x in lines])

# %%
u
# Out:
# 'qismail,i love Looly al7lo'

# %%
u[0
 ]
# Out:
# 'q'
