# %% [raw]
# <script>
#   function code_toggle() {
#     if (code_shown){
#       $('div.input').hide('500');
#       $('#toggleButton').val('Show Code')
#     } else {
#       $('div.input').show('500');
#       $('#toggleButton').val('Hide Code')
#     }
#     code_shown = !code_shown
#   }
#
#   $( document ).ready(function(){
#     code_shown=false;
#     $('div.input').hide()
#   });
# </script>
# <form action="javascript:code_toggle()"><input type="submit" id="toggleButton" value="Show Code"></form>

# %%
#data base connection
import csv
import pandas
from sshtunnel import SSHTunnelForwarder
import pymysql
from tabulate import tabulate

#specifiy the path for your file
with open('/Users/QN/Desktop/THIRD crowdperm/user.txt') as f:
    lines = f.read().splitlines()    
f.close()


server =    SSHTunnelForwarder(
         ('juhu.soic.indiana.edu'),
         ssh_username=lines[0],
         ssh_password=lines[1],
         remote_bind_address=('127.0.0.1', 3306))
server.start()
cnx = pymysql.connect(host='127.0.0.1',
                           port=server.local_bind_port,
                           user='mturk',
                           passwd='m+turk=my-sql',
                           db='mturk')
cnx.set_charset('utf8') 
cursor = cnx.cursor()

query = ("select * from survey2")
cursor.execute(query)

allowAll={"I want to use a specific feature that requires this permission":0,
          "I think the app wont work otherwise":0,
          "I trust the app developer":0,
          "Because the app is popular":0,
          "I wont be able to grant this permission later":0,
          "I have nothing to hide":0,
          "I wanted the permission screen to go away":0,
          "Nothing bad will happen":0,
          "I didnt know I did that":0,
          "I dont know":0,
          "The app developer already has this information about me":0,
          "Other":0}
disAll={"I do not use the specific feature associated with the permission":0,
        "I think the app shouldnt need this permission":0,
        "I expect the app will still work without this permission":0,
        "I consider the permission to be very sensitive":0,
        "I dont trust the developer enough to provide this information":0,
        "I can always grant it afterwards if I change my mind":0,
        "I wanted the permission screen to go away":0,
        "I think something bad might happen if I provide this permission":0,
        "I didnt know I did that":0,
        "I dont know":0,
        "I dont use the app":0,
        "The app did not ask for that permission/I did not disable the permission/I think thats the default setting":0,
        "Other":0}

for row in cursor:
    reasonY = row[18].split(',')
    reasonN = row[20].split(',')
    for x in reasonY:
        x = x.lstrip()
        x = x.rstrip()
        x=x.replace('\'','')
        x=x.replace('\\','')
        if x[0:5] == "Other": allowAll["Other"] += 1
        elif x=="NA": pass
        elif x == "I want to use a specific feature that requires this permission": allowAll[x] += 1
        elif x == "I think the app wont work otherwise": allowAll[x] += 1
        elif x == "I trust the app developer": allowAll[x] += 1
        elif x == "Because the app is popular": allowAll[x] += 1
        elif x=="I wont be able to grant this permission later":allowAll[x] += 1
        elif x== "I have nothing to hide":allowAll[x] += 1
        elif x== "I wanted the permission screen to go away":allowAll[x] += 1
        elif x== "Nothing bad will happen":allowAll[x] += 1
        elif x== "I didnt know I did that":allowAll[x] += 1
        elif x== "I dont know":allowAll[x] += 1
        elif x== "The app developer already has this information about me":allowAll[x] += 1        
        
    
    for x in reasonN:
             
        x = x.lstrip()
        x = x.rstrip()
        x=x.replace('\'','')
        x=x.replace('\\','')
        x=x.replace("thatâ€™s","thats")
        x=x.replace("donâ€™t","dont")
        if x[0:5] == "Other": disAll["Other"] += 1
        elif x=="NA": pass
        elif x=="I do not use the specific feature associated with the permission": disAll[x] += 1
        elif x=="I think the app shouldnt need this permission": disAll[x] += 1
        elif x=="I expect the app will still work without this permission": disAll[x] += 1
        elif x=="I consider the permission to be very sensitive": disAll[x] += 1
        elif x=="I dont trust the developer enough to provide this information": disAll[x] += 1
        elif x=="I can always grant it afterwards if I change my mind": disAll[x] += 1
        elif x=="I wanted the permission screen to go away": disAll[x]+= 1
        elif x=="I think something bad might happen if I provide this permission": disAll[x] += 1
        elif x=="I didnt know I did that": disAll[x] += 1
        elif x=="I dont know": disAll[x] += 1
        elif x=="I dont use the app": disAll[x] += 1
        elif x=="The app did not ask for that permission/I did not disable the permission/I think thats the default setting": disAll[x] += 1

allAllow = []
for key in allowAll:
    temp = []
    temp.append(key)
    temp.append(allowAll[key])
    allAllow.append(temp)
allDis = []
for key in disAll:
    temp = []
    #make this spesific key shorter for display purposes 
    if key== "The app did not ask for that permission/I did not disable the permission/I think thats the default setting":
        temp.append("The app didn't ask for it/I didn't disable it/I think thats the default setting"+'')    
    else:
         temp.append(key+'')  
    temp.append(disAll[key])
    allDis.append(temp)

allow = pandas.DataFrame(allAllow,columns=['Reason','Count'])
disallow = pandas.DataFrame(allDis,columns=['Reason','Count'])

# %% [markdown]
# The most chosen reasons for allowing All permissions:
# - I want to use a specific feature that requires this permission
# - I trust the app developer
# - I think the app wont work otherwise
# - I have nothing to hide

# %%
print(tabulate(allow, showindex=False, headers=allow.columns,tablefmt='psql'))
# Out:
# +----------------------------------------------------------------+---------+
# | Reason                                                         |   Count |
# |----------------------------------------------------------------+---------|
# | I want to use a specific feature that requires this permission |     104 |
# | I think the app wont work otherwise                            |      72 |
# | I trust the app developer                                      |      96 |
# | Because the app is popular                                     |      23 |
# | I wont be able to grant this permission later                  |       0 |
# | I have nothing to hide                                         |      54 |
# | I wanted the permission screen to go away                      |      33 |
# | Nothing bad will happen                                        |      32 |
# | I didnt know I did that                                        |      32 |
# | I dont know                                                    |      20 |
# | The app developer already has this information about me        |      12 |
# | Other                                                          |       3 |
# +----------------------------------------------------------------+---------+

# %% [markdown]
# The most chosen reasons for denying all permissions:
# - I dont use the app
# - I think the app shouldnt need this permission
# - I can always grant it afterwards if I change my mind
# - The app didn't ask for it/I didn't disable it/I think thats the default setting

# %%
print(tabulate(disallow, showindex=False, headers=disallow.columns,tablefmt='psql'))
# Out:
# +---------------------------------------------------------------------------------+---------+
# | Reason                                                                          |   Count |
# |---------------------------------------------------------------------------------+---------|
# | I do not use the specific feature associated with the permission                |      30 |
# | I think the app shouldnt need this permission                                   |      47 |
# | I expect the app will still work without this permission                        |      39 |
# | I consider the permission to be very sensitive                                  |      19 |
# | I dont trust the developer enough to provide this information                   |      18 |
# | I can always grant it afterwards if I change my mind                            |      45 |
# | I wanted the permission screen to go away                                       |       4 |
# | I think something bad might happen if I provide this permission                 |       9 |
# | I didnt know I did that                                                         |      36 |
# | I dont know                                                                     |      22 |
# | I dont use the app                                                              |      80 |
# | The app didn't ask for it/I didn't disable it/I think thats the default setting |      46 |
# | Other                                                                           |       2 |
# +---------------------------------------------------------------------------------+---------+

# %% [markdown]
# The most chosen reasons for allowing Location:
# - I want to use a specific feature that requires this permission
# - I trust the app developer
# - I think the app wont work otherwise
# - I didnt know I did that
#
#
#
# The most chosen reasons for denying Location:
# - I think the app shouldnt need this permission
# - I expect the app will still work without this permission
# - I do not use the specific feature associated with the permission
# - I can always grant it afterwards if I change my mind

# %%
##### for micophone
query = ("select * from survey2 where permission='LOCATION'")
cursor.execute(query)

allowAll={"I want to use a specific feature that requires this permission":0,
          "I think the app wont work otherwise":0,
          "I trust the app developer":0,
          "Because the app is popular":0,
          "I wont be able to grant this permission later":0,
          "I have nothing to hide":0,
          "I wanted the permission screen to go away":0,
          "Nothing bad will happen":0,
          "I didnt know I did that":0,
          "I dont know":0,
          "The app developer already has this information about me":0,
          "Other":0}
disAll={"I do not use the specific feature associated with the permission":0,
        "I think the app shouldnt need this permission":0,
        "I expect the app will still work without this permission":0,
        "I consider the permission to be very sensitive":0,
        "I dont trust the developer enough to provide this information":0,
        "I can always grant it afterwards if I change my mind":0,
        "I wanted the permission screen to go away":0,
        "I think something bad might happen if I provide this permission":0,
        "I didnt know I did that":0,
        "I dont know":0,
        "I dont use the app":0,
        "The app did not ask for that permission/I did not disable the permission/I think thats the default setting":0,
        "Other":0}

for row in cursor:
    reasonY=[]
    reasonN=[]
    reasonY1 = row[42].split(',')
    reasonY.append(reasonY1)
    reasonY2 = row[43].split(',')
    reasonY.append(reasonY2)
    reasonY3 = row[44].split(',')
    reasonY.append(reasonY3)
    reasonY4 = row[45].split(',')
    reasonY.append(reasonY4)
    reasonY5 = row[46].split(',')
    reasonY.append(reasonY5)
    
    reasonN1 = row[53].split(',')
    reasonN.append(reasonN1)
    reasonN2 = row[55].split(',')
    reasonN.append(reasonN2)
    reasonN3 = row[57].split(',')
    reasonN.append(reasonN3)
    reasonN4 = row[59].split(',')
    reasonN.append(reasonN4)
    reasonN5 = row[61].split(',')
    reasonN.append(reasonN5)
    
    for x1 in reasonY:
        for x in x1:
            x = x.lstrip()
            x = x.rstrip()
            x=x.replace('\'','')
            x=x.replace('\\','')
            if x[0:5] == "Other": allowAll["Other"] += 1
            elif x=="NA": pass
            elif x == "I want to use a specific feature that requires this permission": allowAll[x] += 1
            elif x == "I think the app wont work otherwise": allowAll[x] += 1
            elif x == "I trust the app developer": allowAll[x] += 1
            elif x == "Because the app is popular": allowAll[x] += 1
            elif x=="I wont be able to grant this permission later":allowAll[x] += 1
            elif x== "I have nothing to hide":allowAll[x] += 1
            elif x== "I wanted the permission screen to go away":allowAll[x] += 1
            elif x== "Nothing bad will happen":allowAll[x] += 1
            elif x== "I didnt know I did that":allowAll[x] += 1
            elif x== "I dont know":allowAll[x] += 1
            elif x== "The app developer already has this information about me":allowAll[x] += 1        
        
    for x1 in reasonN:
        for x in x1:
             
            x = x.lstrip()
            x = x.rstrip()
            x=x.replace('\'','')
            x=x.replace('\\','')
            x=x.replace("thatâ€™s","thats")
            x=x.replace("donâ€™t","dont")
            if x[0:5] == "Other": disAll["Other"] += 1
            elif x=="NA": pass
            elif x=="I do not use the specific feature associated with the permission": disAll[x] += 1
            elif x=="I think the app shouldnt need this permission": disAll[x] += 1
            elif x=="I expect the app will still work without this permission": disAll[x] += 1
            elif x=="I consider the permission to be very sensitive": disAll[x] += 1
            elif x=="I dont trust the developer enough to provide this information": disAll[x] += 1
            elif x=="I can always grant it afterwards if I change my mind": disAll[x] += 1
            elif x=="I wanted the permission screen to go away": disAll[x]+= 1
            elif x=="I think something bad might happen if I provide this permission": disAll[x] += 1
            elif x=="I didnt know I did that": disAll[x] += 1
            elif x=="I dont know": disAll[x] += 1
            elif x=="I dont use the app": disAll[x] += 1
            elif x=="The app did not ask for that permission/I did not disable the permission/I think thats the default setting": disAll[x] += 1

allAllow = []
for key in allowAll:
    temp = []
    temp.append(key)
    temp.append(allowAll[key])
    allAllow.append(temp)
allDis = []
for key in disAll:
    temp = []
    #make this spesific key shorter for display purposes 
    if key== "The app did not ask for that permission/I did not disable the permission/I think thats the default setting":
        temp.append("The app didn't ask for it/I didn't disable it/I think thats the default setting"+'')    
    else:
         temp.append(key+'')  
    temp.append(disAll[key])
    allDis.append(temp)

allowM = pandas.DataFrame(allAllow,columns=['Reason:LOCATION:Allow','Count'])
disallowM = pandas.DataFrame(allDis,columns=['Reason:LOCATION:Deny','Count'])
print(tabulate(allowM, showindex=False, headers=allowM.columns,tablefmt='psql'))
print(tabulate(disallowM, showindex=False, headers=disallowM.columns,tablefmt='psql'))
#pandas.set_option('max_colwidth',200)
# Out:
# +----------------------------------------------------------------+---------+
# | Reason:LOCATION:Allow                                          |   Count |
# |----------------------------------------------------------------+---------|
# | I want to use a specific feature that requires this permission |     111 |
# | I think the app wont work otherwise                            |      33 |
# | I trust the app developer                                      |      39 |
# | Because the app is popular                                     |      14 |
# | I wont be able to grant this permission later                  |       1 |
# | I have nothing to hide                                         |      20 |
# | I wanted the permission screen to go away                      |       6 |
# | Nothing bad will happen                                        |      15 |
# | I didnt know I did that                                        |      32 |
# | I dont know                                                    |      20 |
# | The app developer already has this information about me        |      14 |
# | Other                                                          |       2 |
# +----------------------------------------------------------------+---------+
# +---------------------------------------------------------------------------------+---------+
# | Reason:LOCATION:Deny                                                            |   Count |
# |---------------------------------------------------------------------------------+---------|
# | I do not use the specific feature associated with the permission                |       9 |
# | I think the app shouldnt need this permission                                   |      16 |
# | I expect the app will still work without this permission                        |      11 |
# | I consider the permission to be very sensitive                                  |       6 |
# | I dont trust the developer enough to provide this information                   |       3 |
# | I can always grant it afterwards if I change my mind                            |       6 |
# | I wanted the permission screen to go away                                       |       3 |
# | I think something bad might happen if I provide this permission                 |       3 |
# | I didnt know I did that                                                         |       0 |
# | I dont know                                                                     |       1 |
# | I dont use the app                                                              |       5 |
# | The app didn't ask for it/I didn't disable it/I think thats the default setting |       2 |
# | Other                                                                           |       1 |
# +---------------------------------------------------------------------------------+---------+

# %% [markdown]
# The most chosen reasons for allowing Microphone:
# - I want to use a specific feature that requires this permission
# - I trust the app developer
# - I think the app wont work otherwise
# - I didnt know I did that
#
#
#
# The most chosen reasons for denying Microphone:
# - I can always grant it afterwards if I change my mind
# - I expect the app will still work without this permission
# - I think the app shouldnt need this permission
# - I do not use the specific feature associated with the permission

# %%
##### for micophone

query = ("select * from survey2 where permission='MICROPHONE'")
cursor.execute(query)

allowAll={"I want to use a specific feature that requires this permission":0,
          "I think the app wont work otherwise":0,
          "I trust the app developer":0,
          "Because the app is popular":0,
          "I wont be able to grant this permission later":0,
          "I have nothing to hide":0,
          "I wanted the permission screen to go away":0,
          "Nothing bad will happen":0,
          "I didnt know I did that":0,
          "I dont know":0,
          "The app developer already has this information about me":0,
          "Other":0}
disAll={"I do not use the specific feature associated with the permission":0,
        "I think the app shouldnt need this permission":0,
        "I expect the app will still work without this permission":0,
        "I consider the permission to be very sensitive":0,
        "I dont trust the developer enough to provide this information":0,
        "I can always grant it afterwards if I change my mind":0,
        "I wanted the permission screen to go away":0,
        "I think something bad might happen if I provide this permission":0,
        "I didnt know I did that":0,
        "I dont know":0,
        "I dont use the app":0,
        "The app did not ask for that permission/I did not disable the permission/I think thats the default setting":0,
        "Other":0}

for row in cursor:
    reasonY=[]
    reasonN=[]
    reasonY1 = row[42].split(',')
    reasonY.append(reasonY1)
    reasonY2 = row[43].split(',')
    reasonY.append(reasonY2)
    reasonY3 = row[44].split(',')
    reasonY.append(reasonY3)
    reasonY4 = row[45].split(',')
    reasonY.append(reasonY4)
    reasonY5 = row[46].split(',')
    reasonY.append(reasonY5)
    
    reasonN1 = row[53].split(',')
    reasonN.append(reasonN1)
    reasonN2 = row[55].split(',')
    reasonN.append(reasonN2)
    reasonN3 = row[57].split(',')
    reasonN.append(reasonN3)
    reasonN4 = row[59].split(',')
    reasonN.append(reasonN4)
    reasonN5 = row[61].split(',')
    reasonN.append(reasonN5)
    
    for x1 in reasonY:
        for x in x1:
            x = x.lstrip()
            x = x.rstrip()
            x=x.replace('\'','')
            x=x.replace('\\','')
            if x[0:5] == "Other": allowAll["Other"] += 1
            elif x=="NA": pass
            elif x == "I want to use a specific feature that requires this permission": allowAll[x] += 1
            elif x == "I think the app wont work otherwise": allowAll[x] += 1
            elif x == "I trust the app developer": allowAll[x] += 1
            elif x == "Because the app is popular": allowAll[x] += 1
            elif x=="I wont be able to grant this permission later":allowAll[x] += 1
            elif x== "I have nothing to hide":allowAll[x] += 1
            elif x== "I wanted the permission screen to go away":allowAll[x] += 1
            elif x== "Nothing bad will happen":allowAll[x] += 1
            elif x== "I didnt know I did that":allowAll[x] += 1
            elif x== "I dont know":allowAll[x] += 1
            elif x== "The app developer already has this information about me":allowAll[x] += 1        
        
    for x1 in reasonN:
        for x in x1:
             
            x = x.lstrip()
            x = x.rstrip()
            x=x.replace('\'','')
            x=x.replace('\\','')
            x=x.replace("thatâ€™s","thats")
            x=x.replace("donâ€™t","dont")
            if x[0:5] == "Other": disAll["Other"] += 1
            elif x=="NA": pass
            elif x=="I do not use the specific feature associated with the permission": disAll[x] += 1
            elif x=="I think the app shouldnt need this permission": disAll[x] += 1
            elif x=="I expect the app will still work without this permission": disAll[x] += 1
            elif x=="I consider the permission to be very sensitive": disAll[x] += 1
            elif x=="I dont trust the developer enough to provide this information": disAll[x] += 1
            elif x=="I can always grant it afterwards if I change my mind": disAll[x] += 1
            elif x=="I wanted the permission screen to go away": disAll[x]+= 1
            elif x=="I think something bad might happen if I provide this permission": disAll[x] += 1
            elif x=="I didnt know I did that": disAll[x] += 1
            elif x=="I dont know": disAll[x] += 1
            elif x=="I dont use the app": disAll[x] += 1
            elif x=="The app did not ask for that permission/I did not disable the permission/I think thats the default setting": disAll[x] += 1

allAllow = []
for key in allowAll:
    temp = []
    temp.append(key)
    temp.append(allowAll[key])
    allAllow.append(temp)
allDis = []
for key in disAll:
    temp = []
    #make this spesific key shorter for display purposes 
    if key== "The app did not ask for that permission/I did not disable the permission/I think thats the default setting":
        temp.append("The app didn't ask for it/I didn't disable it/I think thats the default setting"+'')    
    else:
         temp.append(key+'')  
    temp.append(disAll[key])
    allDis.append(temp)

allowM = pandas.DataFrame(allAllow,columns=['Reason:MICROPHONE:Allow','Count'])
disallowM = pandas.DataFrame(allDis,columns=['Reason:MICROPHONE:Deny','Count'])
print(tabulate(allowM, showindex=False, headers=allowM.columns,tablefmt='psql'))
print(tabulate(disallowM, showindex=False, headers=disallowM.columns,tablefmt='psql'))
#pandas.set_option('max_colwidth',200)
# Out:
# +----------------------------------------------------------------+---------+
# | Reason:MICROPHONE:Allow                                        |   Count |
# |----------------------------------------------------------------+---------|
# | I want to use a specific feature that requires this permission |      54 |
# | I think the app wont work otherwise                            |      18 |
# | I trust the app developer                                      |      29 |
# | Because the app is popular                                     |       5 |
# | I wont be able to grant this permission later                  |       2 |
# | I have nothing to hide                                         |      19 |
# | I wanted the permission screen to go away                      |       8 |
# | Nothing bad will happen                                        |       6 |
# | I didnt know I did that                                        |      24 |
# | I dont know                                                    |       8 |
# | The app developer already has this information about me        |       6 |
# | Other                                                          |       0 |
# +----------------------------------------------------------------+---------+
# +---------------------------------------------------------------------------------+---------+
# | Reason:MICROPHONE:Deny                                                          |   Count |
# |---------------------------------------------------------------------------------+---------|
# | I do not use the specific feature associated with the permission                |       9 |
# | I think the app shouldnt need this permission                                   |       9 |
# | I expect the app will still work without this permission                        |      10 |
# | I consider the permission to be very sensitive                                  |       5 |
# | I dont trust the developer enough to provide this information                   |       2 |
# | I can always grant it afterwards if I change my mind                            |      11 |
# | I wanted the permission screen to go away                                       |       1 |
# | I think something bad might happen if I provide this permission                 |       0 |
# | I didnt know I did that                                                         |       0 |
# | I dont know                                                                     |       1 |
# | I dont use the app                                                              |       3 |
# | The app didn't ask for it/I didn't disable it/I think thats the default setting |       2 |
# | Other                                                                           |       0 |
# +---------------------------------------------------------------------------------+---------+

# %%
##### for camera
query = ("select * from survey2 where permission='CAMERA'")
cursor.execute(query)

allowAll={"I want to use a specific feature that requires this permission":0,
          "I think the app wont work otherwise":0,
          "I trust the app developer":0,
          "Because the app is popular":0,
          "I wont be able to grant this permission later":0,
          "I have nothing to hide":0,
          "I wanted the permission screen to go away":0,
          "Nothing bad will happen":0,
          "I didnt know I did that":0,
          "I dont know":0,
          "The app developer already has this information about me":0,
          "Other":0}
disAll={"I do not use the specific feature associated with the permission":0,
        "I think the app shouldnt need this permission":0,
        "I expect the app will still work without this permission":0,
        "I consider the permission to be very sensitive":0,
        "I dont trust the developer enough to provide this information":0,
        "I can always grant it afterwards if I change my mind":0,
        "I wanted the permission screen to go away":0,
        "I think something bad might happen if I provide this permission":0,
        "I didnt know I did that":0,
        "I dont know":0,
        "I dont use the app":0,
        "The app did not ask for that permission/I did not disable the permission/I think thats the default setting":0,
        "Other":0}

for row in cursor:
    reasonY=[]
    reasonN=[]
    reasonY1 = row[42].split(',')
    reasonY.append(reasonY1)
    reasonY2 = row[43].split(',')
    reasonY.append(reasonY2)
    reasonY3 = row[44].split(',')
    reasonY.append(reasonY3)
    reasonY4 = row[45].split(',')
    reasonY.append(reasonY4)
    reasonY5 = row[46].split(',')
    reasonY.append(reasonY5)
    
    reasonN1 = row[53].split(',')
    reasonN.append(reasonN1)
    reasonN2 = row[55].split(',')
    reasonN.append(reasonN2)
    reasonN3 = row[57].split(',')
    reasonN.append(reasonN3)
    reasonN4 = row[59].split(',')
    reasonN.append(reasonN4)
    reasonN5 = row[61].split(',')
    reasonN.append(reasonN5)
    
    for x1 in reasonY:
        for x in x1:
            x = x.lstrip()
            x = x.rstrip()
            x=x.replace('\'','')
            x=x.replace('\\','')
            if x[0:5] == "Other": allowAll["Other"] += 1
            elif x=="NA": pass
            elif x == "I want to use a specific feature that requires this permission": allowAll[x] += 1
            elif x == "I think the app wont work otherwise": allowAll[x] += 1
            elif x == "I trust the app developer": allowAll[x] += 1
            elif x == "Because the app is popular": allowAll[x] += 1
            elif x=="I wont be able to grant this permission later":allowAll[x] += 1
            elif x== "I have nothing to hide":allowAll[x] += 1
            elif x== "I wanted the permission screen to go away":allowAll[x] += 1
            elif x== "Nothing bad will happen":allowAll[x] += 1
            elif x== "I didnt know I did that":allowAll[x] += 1
            elif x== "I dont know":allowAll[x] += 1
            elif x== "The app developer already has this information about me":allowAll[x] += 1        
        
    for x1 in reasonN:
        for x in x1:
             
            x = x.lstrip()
            x = x.rstrip()
            x=x.replace('\'','')
            x=x.replace('\\','')
            x=x.replace("thatâ€™s","thats")
            x=x.replace("donâ€™t","dont")
            if x[0:5] == "Other": disAll["Other"] += 1
            elif x=="NA": pass
            elif x=="I do not use the specific feature associated with the permission": disAll[x] += 1
            elif x=="I think the app shouldnt need this permission": disAll[x] += 1
            elif x=="I expect the app will still work without this permission": disAll[x] += 1
            elif x=="I consider the permission to be very sensitive": disAll[x] += 1
            elif x=="I dont trust the developer enough to provide this information": disAll[x] += 1
            elif x=="I can always grant it afterwards if I change my mind": disAll[x] += 1
            elif x=="I wanted the permission screen to go away": disAll[x]+= 1
            elif x=="I think something bad might happen if I provide this permission": disAll[x] += 1
            elif x=="I didnt know I did that": disAll[x] += 1
            elif x=="I dont know": disAll[x] += 1
            elif x=="I dont use the app": disAll[x] += 1
            elif x=="The app did not ask for that permission/I did not disable the permission/I think thats the default setting": disAll[x] += 1

allAllow = []
for key in allowAll:
    temp = []
    temp.append(key)
    temp.append(allowAll[key])
    allAllow.append(temp)
allDis = []
for key in disAll:
    temp = []
    #make this spesific key shorter for display purposes 
    if key== "The app did not ask for that permission/I did not disable the permission/I think thats the default setting":
        temp.append("The app didn't ask for it/I didn't disable it/I think thats the default setting"+'')    
    else:
         temp.append(key+'')  
    temp.append(disAll[key])
    allDis.append(temp)


allowM = pandas.DataFrame(allAllow,columns=['Reason:CAMERA:Allow','Count'])
disallowM = pandas.DataFrame(allDis,columns=['Reason:CAMERA:Deny','Count'])
print(tabulate(allowM, showindex=False, headers=allowM.columns,tablefmt='psql'))
print(tabulate(disallowM, showindex=False, headers=disallowM.columns,tablefmt='psql'))
#pandas.set_option('max_colwidth',200)
# Out:
# +----------------------------------------------------------------+---------+
# | Reason:CAMERA:Allow                                            |   Count |
# |----------------------------------------------------------------+---------|
# | I want to use a specific feature that requires this permission |      83 |
# | I think the app wont work otherwise                            |      13 |
# | I trust the app developer                                      |      31 |
# | Because the app is popular                                     |       7 |
# | I wont be able to grant this permission later                  |       2 |
# | I have nothing to hide                                         |      15 |
# | I wanted the permission screen to go away                      |       7 |
# | Nothing bad will happen                                        |       8 |
# | I didnt know I did that                                        |      20 |
# | I dont know                                                    |      10 |
# | The app developer already has this information about me        |       3 |
# | Other                                                          |       3 |
# +----------------------------------------------------------------+---------+
# +---------------------------------------------------------------------------------+---------+
# | Reason:CAMERA:Deny                                                              |   Count |
# |---------------------------------------------------------------------------------+---------|
# | I do not use the specific feature associated with the permission                |       8 |
# | I think the app shouldnt need this permission                                   |      12 |
# | I expect the app will still work without this permission                        |      10 |
# | I consider the permission to be very sensitive                                  |       4 |
# | I dont trust the developer enough to provide this information                   |       5 |
# | I can always grant it afterwards if I change my mind                            |       6 |
# | I wanted the permission screen to go away                                       |       2 |
# | I think something bad might happen if I provide this permission                 |       0 |
# | I didnt know I did that                                                         |       1 |
# | I dont know                                                                     |       0 |
# | I dont use the app                                                              |       7 |
# | The app didn't ask for it/I didn't disable it/I think thats the default setting |       1 |
# | Other                                                                           |       0 |
# +---------------------------------------------------------------------------------+---------+

# %%
##### for contacts
query = ("select * from survey2 where permission='CONTACTS'")
cursor.execute(query)

allowAll={"I want to use a specific feature that requires this permission":0,
          "I think the app wont work otherwise":0,
          "I trust the app developer":0,
          "Because the app is popular":0,
          "I wont be able to grant this permission later":0,
          "I have nothing to hide":0,
          "I wanted the permission screen to go away":0,
          "Nothing bad will happen":0,
          "I didnt know I did that":0,
          "I dont know":0,
          "The app developer already has this information about me":0,
          "Other":0}
disAll={"I do not use the specific feature associated with the permission":0,
        "I think the app shouldnt need this permission":0,
        "I expect the app will still work without this permission":0,
        "I consider the permission to be very sensitive":0,
        "I dont trust the developer enough to provide this information":0,
        "I can always grant it afterwards if I change my mind":0,
        "I wanted the permission screen to go away":0,
        "I think something bad might happen if I provide this permission":0,
        "I didnt know I did that":0,
        "I dont know":0,
        "I dont use the app":0,
        "The app did not ask for that permission/I did not disable the permission/I think thats the default setting":0,
        "Other":0}

for row in cursor:
    reasonY=[]
    reasonN=[]
    reasonY1 = row[42].split(',')
    reasonY.append(reasonY1)
    reasonY2 = row[43].split(',')
    reasonY.append(reasonY2)
    reasonY3 = row[44].split(',')
    reasonY.append(reasonY3)
    reasonY4 = row[45].split(',')
    reasonY.append(reasonY4)
    reasonY5 = row[46].split(',')
    reasonY.append(reasonY5)
    
    reasonN1 = row[53].split(',')
    reasonN.append(reasonN1)
    reasonN2 = row[55].split(',')
    reasonN.append(reasonN2)
    reasonN3 = row[57].split(',')
    reasonN.append(reasonN3)
    reasonN4 = row[59].split(',')
    reasonN.append(reasonN4)
    reasonN5 = row[61].split(',')
    reasonN.append(reasonN5)
    
    for x1 in reasonY:
        for x in x1:
            x = x.lstrip()
            x = x.rstrip()
            x=x.replace('\'','')
            x=x.replace('\\','')
            if x[0:5] == "Other": allowAll["Other"] += 1
            elif x=="NA": pass
            elif x == "I want to use a specific feature that requires this permission": allowAll[x] += 1
            elif x == "I think the app wont work otherwise": allowAll[x] += 1
            elif x == "I trust the app developer": allowAll[x] += 1
            elif x == "Because the app is popular": allowAll[x] += 1
            elif x=="I wont be able to grant this permission later":allowAll[x] += 1
            elif x== "I have nothing to hide":allowAll[x] += 1
            elif x== "I wanted the permission screen to go away":allowAll[x] += 1
            elif x== "Nothing bad will happen":allowAll[x] += 1
            elif x== "I didnt know I did that":allowAll[x] += 1
            elif x== "I dont know":allowAll[x] += 1
            elif x== "The app developer already has this information about me":allowAll[x] += 1        
        
    for x1 in reasonN:
        for x in x1:
             
            x = x.lstrip()
            x = x.rstrip()
            x=x.replace('\'','')
            x=x.replace('\\','')
            x=x.replace("thatâ€™s","thats")
            x=x.replace("donâ€™t","dont")
            if x[0:5] == "Other": disAll["Other"] += 1
            elif x=="NA": pass
            elif x=="I do not use the specific feature associated with the permission": disAll[x] += 1
            elif x=="I think the app shouldnt need this permission": disAll[x] += 1
            elif x=="I expect the app will still work without this permission": disAll[x] += 1
            elif x=="I consider the permission to be very sensitive": disAll[x] += 1
            elif x=="I dont trust the developer enough to provide this information": disAll[x] += 1
            elif x=="I can always grant it afterwards if I change my mind": disAll[x] += 1
            elif x=="I wanted the permission screen to go away": disAll[x]+= 1
            elif x=="I think something bad might happen if I provide this permission": disAll[x] += 1
            elif x=="I didnt know I did that": disAll[x] += 1
            elif x=="I dont know": disAll[x] += 1
            elif x=="I dont use the app": disAll[x] += 1
            elif x=="The app did not ask for that permission/I did not disable the permission/I think thats the default setting": disAll[x] += 1

allAllow = []
for key in allowAll:
    temp = []
    temp.append(key)
    temp.append(allowAll[key])
    allAllow.append(temp)
allDis = []
for key in disAll:
    temp = []
    #make this spesific key shorter for display purposes 
    if key== "The app did not ask for that permission/I did not disable the permission/I think thats the default setting":
        temp.append("The app didn't ask for it/I didn't disable it/I think thats the default setting"+'')    
    else:
         temp.append(key+'')  
    temp.append(disAll[key])
    allDis.append(temp)



allowM = pandas.DataFrame(allAllow,columns=['Reason:CONTACTS:Allow','Count'])
disallowM = pandas.DataFrame(allDis,columns=['Reason:CONTACTS:Deny','Count'])
print(tabulate(allowM, showindex=False, headers=allowM.columns,tablefmt='psql'))
print(tabulate(disallowM, showindex=False, headers=disallowM.columns,tablefmt='psql'))
#pandas.set_option('max_colwidth',200)
# Out:
# +----------------------------------------------------------------+---------+
# | Reason:CONTACTS:Allow                                          |   Count |
# |----------------------------------------------------------------+---------|
# | I want to use a specific feature that requires this permission |      48 |
# | I think the app wont work otherwise                            |      17 |
# | I trust the app developer                                      |      43 |
# | Because the app is popular                                     |      14 |
# | I wont be able to grant this permission later                  |       0 |
# | I have nothing to hide                                         |      25 |
# | I wanted the permission screen to go away                      |       5 |
# | Nothing bad will happen                                        |      23 |
# | I didnt know I did that                                        |      35 |
# | I dont know                                                    |      25 |
# | The app developer already has this information about me        |      11 |
# | Other                                                          |       2 |
# +----------------------------------------------------------------+---------+
# +---------------------------------------------------------------------------------+---------+
# | Reason:CONTACTS:Deny                                                            |   Count |
# |---------------------------------------------------------------------------------+---------|
# | I do not use the specific feature associated with the permission                |      11 |
# | I think the app shouldnt need this permission                                   |      18 |
# | I expect the app will still work without this permission                        |      14 |
# | I consider the permission to be very sensitive                                  |       0 |
# | I dont trust the developer enough to provide this information                   |       5 |
# | I can always grant it afterwards if I change my mind                            |       6 |
# | I wanted the permission screen to go away                                       |       0 |
# | I think something bad might happen if I provide this permission                 |       3 |
# | I didnt know I did that                                                         |       0 |
# | I dont know                                                                     |       1 |
# | I dont use the app                                                              |       0 |
# | The app didn't ask for it/I didn't disable it/I think thats the default setting |       1 |
# | Other                                                                           |       0 |
# +---------------------------------------------------------------------------------+---------+

# %%
##### for phone
query = ("select * from survey2 where permission='PHONE'")
cursor.execute(query)

allowAll={"I want to use a specific feature that requires this permission":0,
          "I think the app wont work otherwise":0,
          "I trust the app developer":0,
          "Because the app is popular":0,
          "I wont be able to grant this permission later":0,
          "I have nothing to hide":0,
          "I wanted the permission screen to go away":0,
          "Nothing bad will happen":0,
          "I didnt know I did that":0,
          "I dont know":0,
          "The app developer already has this information about me":0,
          "Other":0}
disAll={"I do not use the specific feature associated with the permission":0,
        "I think the app shouldnt need this permission":0,
        "I expect the app will still work without this permission":0,
        "I consider the permission to be very sensitive":0,
        "I dont trust the developer enough to provide this information":0,
        "I can always grant it afterwards if I change my mind":0,
        "I wanted the permission screen to go away":0,
        "I think something bad might happen if I provide this permission":0,
        "I didnt know I did that":0,
        "I dont know":0,
        "I dont use the app":0,
        "The app did not ask for that permission/I did not disable the permission/I think thats the default setting":0,
        "Other":0}

for row in cursor:
    reasonY=[]
    reasonN=[]
    reasonY1 = row[42].split(',')
    reasonY.append(reasonY1)
    reasonY2 = row[43].split(',')
    reasonY.append(reasonY2)
    reasonY3 = row[44].split(',')
    reasonY.append(reasonY3)
    reasonY4 = row[45].split(',')
    reasonY.append(reasonY4)
    reasonY5 = row[46].split(',')
    reasonY.append(reasonY5)
    
    reasonN1 = row[53].split(',')
    reasonN.append(reasonN1)
    reasonN2 = row[55].split(',')
    reasonN.append(reasonN2)
    reasonN3 = row[57].split(',')
    reasonN.append(reasonN3)
    reasonN4 = row[59].split(',')
    reasonN.append(reasonN4)
    reasonN5 = row[61].split(',')
    reasonN.append(reasonN5)
    
    for x1 in reasonY:
        for x in x1:
            x = x.lstrip()
            x = x.rstrip()
            x=x.replace('\'','')
            x=x.replace('\\','')
            if x[0:5] == "Other": allowAll["Other"] += 1
            elif x=="NA": pass
            elif x == "I want to use a specific feature that requires this permission": allowAll[x] += 1
            elif x == "I think the app wont work otherwise": allowAll[x] += 1
            elif x == "I trust the app developer": allowAll[x] += 1
            elif x == "Because the app is popular": allowAll[x] += 1
            elif x=="I wont be able to grant this permission later":allowAll[x] += 1
            elif x== "I have nothing to hide":allowAll[x] += 1
            elif x== "I wanted the permission screen to go away":allowAll[x] += 1
            elif x== "Nothing bad will happen":allowAll[x] += 1
            elif x== "I didnt know I did that":allowAll[x] += 1
            elif x== "I dont know":allowAll[x] += 1
            elif x== "The app developer already has this information about me":allowAll[x] += 1        
        
    for x1 in reasonN:
        for x in x1:
             
            x = x.lstrip()
            x = x.rstrip()
            x=x.replace('\'','')
            x=x.replace('\\','')
            x=x.replace("thatâ€™s","thats")
            x=x.replace("donâ€™t","dont")
            if x[0:5] == "Other": disAll["Other"] += 1
            elif x=="NA": pass
            elif x=="I do not use the specific feature associated with the permission": disAll[x] += 1
            elif x=="I think the app shouldnt need this permission": disAll[x] += 1
            elif x=="I expect the app will still work without this permission": disAll[x] += 1
            elif x=="I consider the permission to be very sensitive": disAll[x] += 1
            elif x=="I dont trust the developer enough to provide this information": disAll[x] += 1
            elif x=="I can always grant it afterwards if I change my mind": disAll[x] += 1
            elif x=="I wanted the permission screen to go away": disAll[x]+= 1
            elif x=="I think something bad might happen if I provide this permission": disAll[x] += 1
            elif x=="I didnt know I did that": disAll[x] += 1
            elif x=="I dont know": disAll[x] += 1
            elif x=="I dont use the app": disAll[x] += 1
            elif x=="The app did not ask for that permission/I did not disable the permission/I think thats the default setting": disAll[x] += 1

allAllow = []
for key in allowAll:
    temp = []
    temp.append(key)
    temp.append(allowAll[key])
    allAllow.append(temp)
allDis = []
for key in disAll:
    temp = []
    #make this spesific key shorter for display purposes 
    if key== "The app did not ask for that permission/I did not disable the permission/I think thats the default setting":
        temp.append("The app didn't ask for it/I didn't disable it/I think thats the default setting"+'')    
    else:
         temp.append(key+'')  
    temp.append(disAll[key])
    allDis.append(temp)



allowM = pandas.DataFrame(allAllow,columns=['Reason:PHONE:Allow','Count'])
disallowM = pandas.DataFrame(allDis,columns=['Reason:PHONE:Deny','Count'])
print(tabulate(allowM, showindex=False, headers=allowM.columns,tablefmt='psql'))
print(tabulate(disallowM, showindex=False, headers=disallowM.columns,tablefmt='psql'))
#pandas.set_option('max_colwidth',200)
# Out:
# +----------------------------------------------------------------+---------+
# | Reason:PHONE:Allow                                             |   Count |
# |----------------------------------------------------------------+---------|
# | I want to use a specific feature that requires this permission |      41 |
# | I think the app wont work otherwise                            |      23 |
# | I trust the app developer                                      |      27 |
# | Because the app is popular                                     |       7 |
# | I wont be able to grant this permission later                  |       0 |
# | I have nothing to hide                                         |      17 |
# | I wanted the permission screen to go away                      |      10 |
# | Nothing bad will happen                                        |      10 |
# | I didnt know I did that                                        |      43 |
# | I dont know                                                    |      12 |
# | The app developer already has this information about me        |       5 |
# | Other                                                          |       4 |
# +----------------------------------------------------------------+---------+
# +---------------------------------------------------------------------------------+---------+
# | Reason:PHONE:Deny                                                               |   Count |
# |---------------------------------------------------------------------------------+---------|
# | I do not use the specific feature associated with the permission                |       7 |
# | I think the app shouldnt need this permission                                   |      20 |
# | I expect the app will still work without this permission                        |      18 |
# | I consider the permission to be very sensitive                                  |       4 |
# | I dont trust the developer enough to provide this information                   |       0 |
# | I can always grant it afterwards if I change my mind                            |       9 |
# | I wanted the permission screen to go away                                       |       1 |
# | I think something bad might happen if I provide this permission                 |       1 |
# | I didnt know I did that                                                         |       0 |
# | I dont know                                                                     |       0 |
# | I dont use the app                                                              |       3 |
# | The app didn't ask for it/I didn't disable it/I think thats the default setting |       2 |
# | Other                                                                           |       0 |
# +---------------------------------------------------------------------------------+---------+

# %%
##### for storage
query = ("select * from survey2 where permission='STORAGE'")
cursor.execute(query)

allowAll={"I want to use a specific feature that requires this permission":0,
          "I think the app wont work otherwise":0,
          "I trust the app developer":0,
          "Because the app is popular":0,
          "I wont be able to grant this permission later":0,
          "I have nothing to hide":0,
          "I wanted the permission screen to go away":0,
          "Nothing bad will happen":0,
          "I didnt know I did that":0,
          "I dont know":0,
          "The app developer already has this information about me":0,
          "Other":0}
disAll={"I do not use the specific feature associated with the permission":0,
        "I think the app shouldnt need this permission":0,
        "I expect the app will still work without this permission":0,
        "I consider the permission to be very sensitive":0,
        "I dont trust the developer enough to provide this information":0,
        "I can always grant it afterwards if I change my mind":0,
        "I wanted the permission screen to go away":0,
        "I think something bad might happen if I provide this permission":0,
        "I didnt know I did that":0,
        "I dont know":0,
        "I dont use the app":0,
        "The app did not ask for that permission/I did not disable the permission/I think thats the default setting":0,
        "Other":0}

for row in cursor:
    reasonY=[]
    reasonN=[]
    reasonY1 = row[42].split(',')
    reasonY.append(reasonY1)
    reasonY2 = row[43].split(',')
    reasonY.append(reasonY2)
    reasonY3 = row[44].split(',')
    reasonY.append(reasonY3)
    reasonY4 = row[45].split(',')
    reasonY.append(reasonY4)
    reasonY5 = row[46].split(',')
    reasonY.append(reasonY5)
    
    reasonN1 = row[53].split(',')
    reasonN.append(reasonN1)
    reasonN2 = row[55].split(',')
    reasonN.append(reasonN2)
    reasonN3 = row[57].split(',')
    reasonN.append(reasonN3)
    reasonN4 = row[59].split(',')
    reasonN.append(reasonN4)
    reasonN5 = row[61].split(',')
    reasonN.append(reasonN5)
    
    for x1 in reasonY:
        for x in x1:
            x = x.lstrip()
            x = x.rstrip()
            x=x.replace('\'','')
            x=x.replace('\\','')
            if x[0:5] == "Other": allowAll["Other"] += 1
            elif x=="NA": pass
            elif x == "I want to use a specific feature that requires this permission": allowAll[x] += 1
            elif x == "I think the app wont work otherwise": allowAll[x] += 1
            elif x == "I trust the app developer": allowAll[x] += 1
            elif x == "Because the app is popular": allowAll[x] += 1
            elif x=="I wont be able to grant this permission later":allowAll[x] += 1
            elif x== "I have nothing to hide":allowAll[x] += 1
            elif x== "I wanted the permission screen to go away":allowAll[x] += 1
            elif x== "Nothing bad will happen":allowAll[x] += 1
            elif x== "I didnt know I did that":allowAll[x] += 1
            elif x== "I dont know":allowAll[x] += 1
            elif x== "The app developer already has this information about me":allowAll[x] += 1        
        
    for x1 in reasonN:
        for x in x1:
             
            x = x.lstrip()
            x = x.rstrip()
            x=x.replace('\'','')
            x=x.replace('\\','')
            x=x.replace("thatâ€™s","thats")
            x=x.replace("donâ€™t","dont")
            if x[0:5] == "Other": disAll["Other"] += 1
            elif x=="NA": pass
            elif x=="I do not use the specific feature associated with the permission": disAll[x] += 1
            elif x=="I think the app shouldnt need this permission": disAll[x] += 1
            elif x=="I expect the app will still work without this permission": disAll[x] += 1
            elif x=="I consider the permission to be very sensitive": disAll[x] += 1
            elif x=="I dont trust the developer enough to provide this information": disAll[x] += 1
            elif x=="I can always grant it afterwards if I change my mind": disAll[x] += 1
            elif x=="I wanted the permission screen to go away": disAll[x]+= 1
            elif x=="I think something bad might happen if I provide this permission": disAll[x] += 1
            elif x=="I didnt know I did that": disAll[x] += 1
            elif x=="I dont know": disAll[x] += 1
            elif x=="I dont use the app": disAll[x] += 1
            elif x=="The app did not ask for that permission/I did not disable the permission/I think thats the default setting": disAll[x] += 1

allAllow = []
for key in allowAll:
    temp = []
    temp.append(key)
    temp.append(allowAll[key])
    allAllow.append(temp)
allDis = []
for key in disAll:
    temp = []
    #make this spesific key shorter for display purposes 
    if key== "The app did not ask for that permission/I did not disable the permission/I think thats the default setting":
        temp.append("The app didn't ask for it/I didn't disable it/I think thats the default setting"+'')    
    else:
         temp.append(key+'')  
    temp.append(disAll[key])
    allDis.append(temp)



allowM = pandas.DataFrame(allAllow,columns=['Reason:STORAGE:Allow','Count'])
disallowM = pandas.DataFrame(allDis,columns=['Reason:STORAGE:Deny','Count'])
print(tabulate(allowM, showindex=False, headers=allowM.columns,tablefmt='psql'))
print(tabulate(disallowM, showindex=False, headers=disallowM.columns,tablefmt='psql'))
#pandas.set_option('max_colwidth',200)
# Out:
# +----------------------------------------------------------------+---------+
# | Reason:STORAGE:Allow                                           |   Count |
# |----------------------------------------------------------------+---------|
# | I want to use a specific feature that requires this permission |      64 |
# | I think the app wont work otherwise                            |      59 |
# | I trust the app developer                                      |      43 |
# | Because the app is popular                                     |      11 |
# | I wont be able to grant this permission later                  |       1 |
# | I have nothing to hide                                         |      12 |
# | I wanted the permission screen to go away                      |      15 |
# | Nothing bad will happen                                        |      15 |
# | I didnt know I did that                                        |      39 |
# | I dont know                                                    |      34 |
# | The app developer already has this information about me        |       7 |
# | Other                                                          |       0 |
# +----------------------------------------------------------------+---------+
# +---------------------------------------------------------------------------------+---------+
# | Reason:STORAGE:Deny                                                             |   Count |
# |---------------------------------------------------------------------------------+---------|
# | I do not use the specific feature associated with the permission                |       1 |
# | I think the app shouldnt need this permission                                   |       6 |
# | I expect the app will still work without this permission                        |       3 |
# | I consider the permission to be very sensitive                                  |       0 |
# | I dont trust the developer enough to provide this information                   |       3 |
# | I can always grant it afterwards if I change my mind                            |       2 |
# | I wanted the permission screen to go away                                       |       0 |
# | I think something bad might happen if I provide this permission                 |       1 |
# | I didnt know I did that                                                         |       0 |
# | I dont know                                                                     |       2 |
# | I dont use the app                                                              |       1 |
# | The app didn't ask for it/I didn't disable it/I think thats the default setting |       2 |
# | Other                                                                           |       0 |
# +---------------------------------------------------------------------------------+---------+

# %% [markdown]
# ## Enabled permission:
# ### Count the number of times each question was asked for each permission, to be able to calculate the ratio:

# %%
#location
query = ("select comfortableMic from survey2 where permission=\"LOCATION\" and comfortableMic!=''")
cursor.execute(query)
totalLocation=0
cnt=0

for row in cursor:
    cnt=row[0].count(',')
    totalLocation=totalLocation+(cnt+1)

#mic
query = ("select comfortableMic from survey2 where permission=\"MICROPHONE\" and comfortableMic!=''")
cursor.execute(query)
totalMic=0
cnt=0

for row in cursor:
    cnt=row[0].count(',')
    totalMic=totalMic+(cnt+1)

#camera
query = ("select comfortableMic from survey2 where permission=\"CAMERA\" and comfortableMic!=''")
cursor.execute(query)
totalCamera=0
cnt=0

for row in cursor:
    cnt=row[0].count(',')
    totalCamera=totalCamera+(cnt+1)

#contacts
query = ("select comfortableMic from survey2 where permission=\"CONTACTS\" and comfortableMic!=''")
cursor.execute(query)
totalContacts=0
cnt=0

for row in cursor:
    cnt=row[0].count(',')
    totalContacts=totalContacts+(cnt+1)

    
#phone
query = ("select comfortableMic from survey2 where permission=\"PHONE\" and comfortableMic!=''")
cursor.execute(query)
totalPhone=0
cnt=0

for row in cursor:
    cnt=row[0].count(',')
    totalPhone=totalPhone+(cnt+1)

#storage
query = ("select comfortableMic from survey2 where permission=\"STORAGE\" and comfortableMic!=''")
cursor.execute(query)
totalStorage=0
cnt=0

for row in cursor:
    cnt=row[0].count(',')
    totalStorage=totalStorage+(cnt+1)

totalAllEnabled=0
query = ("select count(enabledAllwhy) from survey2 where enabledAllwhy!='NA'")
cursor.execute(query)
for row in cursor:
    totalAllEnabled=row[0]

print ("Loc: ",totalLocation )
print ("mic: ", totalMic)
print ("Cam: ", totalCamera)
print ("Cont: ", totalContacts)
print ("Phone: ", totalPhone)
print ("Storage: ", totalStorage)
print ("AllEnabled: ", totalAllEnabled)
# Out:
# Loc:  213
# mic:  136
# Cam:  154
# Cont:  181
# Phone:  154
# Storage:  210
# AllEnabled:  273

# %% [markdown]
# ## Disabled:
# ### Count the number of times each question was asked for each permission, to be able to calculate the ratio:

# %%
#Location
DisabledLoc=0
query = ("select count(disabledwhyMic1) from survey2 where disabledwhyMic1!='NA' and permission=\"LOCATION\"")
cursor.execute(query)
for row in cursor:
    DisabledLoc=DisabledLoc+row[0]

query = ("select count(disabledwhyMic2) from survey2 where disabledwhyMic2!='NA' and permission=\"LOCATION\"")
cursor.execute(query)
for row in cursor:
    DisabledLoc=DisabledLoc+row[0]

query = ("select count(disabledwhyMic3) from survey2 where disabledwhyMic3!='NA' and permission=\"LOCATION\"")
cursor.execute(query)
for row in cursor:
    DisabledLoc=DisabledLoc+row[0]

query = ("select count(disabledwhyMic4) from survey2 where disabledwhyMic4!='NA' and permission=\"LOCATION\"")
cursor.execute(query)
for row in cursor:
    DisabledLoc=DisabledLoc+row[0]

query = ("select count(disabledwhyMic5) from survey2 where disabledwhyMic5!='NA' and permission=\"LOCATION\"")
cursor.execute(query)
for row in cursor:
    DisabledLoc=DisabledLoc+row[0]

#Mic
DisabledMicrophone=0
query = ("select count(disabledwhyMic1) from survey2 where disabledwhyMic1!='NA' and permission=\"MICROPHONE\"")
cursor.execute(query)
for row in cursor:
    DisabledMicrophone=DisabledMicrophone+row[0]

query = ("select count(disabledwhyMic2) from survey2 where disabledwhyMic2!='NA' and permission=\"MICROPHONE\"")
cursor.execute(query)
for row in cursor:
    DisabledMicrophone=DisabledMicrophone+row[0]

query = ("select count(disabledwhyMic3) from survey2 where disabledwhyMic3!='NA' and permission=\"MICROPHONE\"")
cursor.execute(query)
for row in cursor:
    DisabledMicrophone=DisabledMicrophone+row[0]

query = ("select count(disabledwhyMic4) from survey2 where disabledwhyMic4!='NA' and permission=\"MICROPHONE\"")
cursor.execute(query)
for row in cursor:
    DisabledMicrophone=DisabledMicrophone+row[0]

query = ("select count(disabledwhyMic5) from survey2 where disabledwhyMic5!='NA' and permission=\"MICROPHONE\"")
cursor.execute(query)
for row in cursor:
    DisabledMicrophone=DisabledMicrophone+row[0]
    
#Camera
DisabledCamera=0
query = ("select count(disabledwhyMic1) from survey2 where disabledwhyMic1!='NA' and permission=\"CAMERA\"")
cursor.execute(query)
for row in cursor:
    DisabledCamera=DisabledCamera+row[0]

query = ("select count(disabledwhyMic2) from survey2 where disabledwhyMic2!='NA' and permission=\"CAMERA\"")
cursor.execute(query)
for row in cursor:
    DisabledCamera=DisabledCamera+row[0]

query = ("select count(disabledwhyMic3) from survey2 where disabledwhyMic3!='NA' and permission=\"CAMERA\"")
cursor.execute(query)
for row in cursor:
    DisabledCamera=DisabledCamera+row[0]

query = ("select count(disabledwhyMic4) from survey2 where disabledwhyMic4!='NA' and permission=\"CAMERA\"")
cursor.execute(query)
for row in cursor:
    DisabledCamera=DisabledCamera+row[0]

query = ("select count(disabledwhyMic5) from survey2 where disabledwhyMic5!='NA' and permission=\"CAMERA\"")
cursor.execute(query)
for row in cursor:
    DisabledCamera=DisabledCamera+row[0]
    
#contacts
DisabledContacts=0
query = ("select count(disabledwhyMic1) from survey2 where disabledwhyMic1!='NA' and permission=\"CONTACTS\"")
cursor.execute(query)
for row in cursor:
    DisabledContacts=DisabledContacts+row[0]

query = ("select count(disabledwhyMic2) from survey2 where disabledwhyMic2!='NA' and permission=\"CONTACTS\"")
cursor.execute(query)
for row in cursor:
    DisabledContacts=DisabledContacts+row[0]

query = ("select count(disabledwhyMic3) from survey2 where disabledwhyMic3!='NA' and permission=\"CONTACTS\"")
cursor.execute(query)
for row in cursor:
    DisabledContacts=DisabledContacts+row[0]

query = ("select count(disabledwhyMic4) from survey2 where disabledwhyMic4!='NA' and permission=\"CONTACTS\"")
cursor.execute(query)
for row in cursor:
    DisabledContacts=DisabledContacts+row[0]

query = ("select count(disabledwhyMic5) from survey2 where disabledwhyMic5!='NA' and permission=\"CONTACTS\"")
cursor.execute(query)
for row in cursor:
    DisabledContacts=DisabledContacts+row[0]

#phone
DisabledPhone=0
query = ("select count(disabledwhyMic1) from survey2 where disabledwhyMic1!='NA' and permission=\"PHONE\"")
cursor.execute(query)
for row in cursor:
    DisabledPhone=DisabledPhone+row[0]

query = ("select count(disabledwhyMic2) from survey2 where disabledwhyMic2!='NA' and permission=\"PHONE\"")
cursor.execute(query)
for row in cursor:
    DisabledPhone=DisabledPhone+row[0]

query = ("select count(disabledwhyMic3) from survey2 where disabledwhyMic3!='NA' and permission=\"PHONE\"")
cursor.execute(query)
for row in cursor:
    DisabledPhone=DisabledPhone+row[0]

query = ("select count(disabledwhyMic4) from survey2 where disabledwhyMic4!='NA' and permission=\"PHONE\"")
cursor.execute(query)
for row in cursor:
    DisabledPhone=DisabledPhone+row[0]

query = ("select count(disabledwhyMic5) from survey2 where disabledwhyMic5!='NA' and permission=\"PHONE\"")
cursor.execute(query)
for row in cursor:
    DisabledPhone=DisabledPhone+row[0]
    
    
#storage
DisabledStorage=0
query = ("select count(disabledwhyMic1) from survey2 where disabledwhyMic1!='NA' and permission=\"STORAGE\"")
cursor.execute(query)
for row in cursor:
    DisabledStorage=DisabledStorage+row[0]

query = ("select count(disabledwhyMic2) from survey2 where disabledwhyMic2!='NA' and permission=\"STORAGE\"")
cursor.execute(query)
for row in cursor:
    DisabledStorage=DisabledStorage+row[0]

query = ("select count(disabledwhyMic3) from survey2 where disabledwhyMic3!='NA' and permission=\"STORAGE\"")
cursor.execute(query)
for row in cursor:
    DisabledStorage=DisabledStorage+row[0]

query = ("select count(disabledwhyMic4) from survey2 where disabledwhyMic4!='NA' and permission=\"STORAGE\"")
cursor.execute(query)
for row in cursor:
    DisabledStorage=DisabledStorage+row[0]

query = ("select count(disabledwhyMic5) from survey2 where disabledwhyMic5!='NA' and permission=\"STORAGE\"")
cursor.execute(query)
for row in cursor:
    DisabledStorage=DisabledStorage+row[0]

    
DisabledAll=0
query = ("select count(disabledAll) from survey2 where disabledAll!='NA'")
cursor.execute(query)
for row in cursor:
    DisabledAll=row[0]

print ("Loc: ",DisabledLoc)
print ("mic: ", DisabledMicrophone)
print ("Cam: ", DisabledCamera)
print ("Cont: ", DisabledContacts)
print ("Phone: ", DisabledPhone)
print ("Storage: ", DisabledStorage)
print ("AllEnabled: ", DisabledAll)
# Out:
# Loc:  47
# mic:  37
# Cam:  33
# Cont:  40
# Phone:  35
# Storage:  16
# AllEnabled:  293

# %%
cursor.close()
cnx.close()

# %% [raw]
# <script>
#   $(document).ready(function(){
#     $('div.prompt').hide();
#     $('div.back-to-top').hide();
#     $('nav#menubar').hide();
#     $('.breadcrumb').hide();
#     $('.hidden-print').hide();
#   });
# </script>
#
# <footer id="attribution" style="float:right; color:#999; background:#fff;">
# Created with Jupyter, delivered by Fastly, rendered by Rackspace.
# </footer>
